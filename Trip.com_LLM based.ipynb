# %%
import re
import ast
import pandas as pd
from pathlib import Path
from openai import OpenAI

# %%
# ========== 1. Load the Trip.com hotel search result text ==========
file_path = Path("Siem Reap Hotels - Where to stay in Siem Reap _ Trip.txt")
with open(file_path, "r", encoding="utf-8") as file:
    full_text = file.read()

# ========== 2. Chunk the text using "Show on Map" as hotel delimiter ==========
hotel_blocks = re.split(r"(?=Show on Map)", full_text)
hotel_blocks = [block.strip() for block in hotel_blocks if len(block.strip()) > 200]

# ========== 3. Create a DataFrame for review ==========
df_blocks = pd.DataFrame({"Hotel Block": hotel_blocks})
df_blocks
# Out:
#                                            Hotel Block
# 0    <https://us.trip.com/?locale=en-US&curr=USD>\n...
# 1    Show on Map\n\nSearch Properties\n\n/\n\n/\nBu...
# 2    Show on Map\n  *\n    hotel overview picture\n...
# 3    Show on Map\n\n    Deluxe Twin Room//////\n   ...
# 4    Show on Map\n\n    Deluxe Family Room////////\...
# ..                                                 ...
# 318  Show on Map\n\n    One Bedroom Villa King Size...
# 319  Show on Map\n\n    Superior Double Or Twin Roo...
# 320  Show on Map\n\n    Cabana Room with Pool Acces...
# 321  Show on Map\n\n    Soupier Room With Hot Tub//...
# 322  Show on Map\n\n    Deluxe Room/////////\n    B...
#
# [323 rows x 1 columns]

# %%
api_key = 'sk-9c8a52fa5ba140608bb8484c3a27cffa'

# %%
# ========== 3. Prepare DeepSeek API ==========
client = OpenAI(
    api_key= api_key,  # ← Replace this with your actual key
    base_url="https://api.deepseek.com"
)

system_prompt = (
    "You are processing a printed text block from a Trip.com hotel search result page. "
    "Each block describes one hotel. Extract clearly stated information only.\n\n"
    "Return valid JSON structured like this:\n"
    "{\n"
    "  \"hotel_name\": \"\",\n"
    "  \"distance_miles\": \"\",            # Only numeric, no 'mi' or location names\n"
    "  \"guest_rating_out_of_10\": \"\",    # e.g. '8.6'\n"
    "  \"number_of_reviews\": \"\",         # Numeric only\n"
    "  \"price_usd_total\": \"\",           # Numeric only, no $ or 'total'\n"
    "  \"room_type_or_description\": \"\",\n"
    "  \"amenities\": [\"\", \"\"]\n"
    "}\n\n"
    "Strict rules:\n"
    "- All numeric fields must be clean strings.\n"
    "- Do NOT include units, currency symbols, or extra text.\n"
    "- Use \"N/A\" if the value is not available.\n"
    "- Output must be valid JSON (single object or list of objects)."
)

# ========== 4. Send first 5 blocks to DeepSeek API ==========
results = []

for i, block in enumerate(hotel_blocks):
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": block}
        ],
        temperature=0.0,
        stream=False
    )

    raw = response.choices[0].message.content.strip()
    print(f"\n🔹 Hotel Block {i} - Raw AI Output:\n{raw}\n")

    cleaned = raw.strip("` \n")
    if cleaned.startswith("json"):
        cleaned = cleaned[4:].strip()

    try:
        parsed = ast.literal_eval(cleaned)
        if isinstance(parsed, dict):
            results.append(parsed)
        elif isinstance(parsed, list):
            results.extend(parsed)
        else:
            raise ValueError("Parsed output is not a dict or list")
    except Exception as e:
        print(f"❌ Parse error on block {i}: {e}")
        results.append({
            "hotel_name": "ERROR",
            "distance_miles": "ERROR",
            "guest_rating_out_of_10": "ERROR",
            "number_of_reviews": "ERROR",
            "price_usd_total": "ERROR",
            "room_type_or_description": "ERROR",
            "amenities": ["ERROR"]
        })

# ========== 5. Save to DataFrame ==========
df_trip_structured = pd.DataFrame(results)
# Out:
# 🔹 Hotel Block 0 - Raw AI Output:
# ```json
# {
#   "hotel_name": "N/A",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "N/A",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 1 - Raw AI Output:
# ```json
# []
# ```
#
#
# 🔹 Hotel Block 2 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Steung Siemreap Hotel",
#   "distance_miles": "0.066",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "55",
#   "price_usd_total": "N/A",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 3 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Neth Socheata Hotel",
#   "distance_miles": "0.076",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "29",
#   "price_usd_total": "49",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 4 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Atelier Hotel",
#   "distance_miles": "0.085",
#   "guest_rating_out_of_10": "4.1",
#   "number_of_reviews": "12",
#   "price_usd_total": "34",
#   "room_type_or_description": "Deluxe Family Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 5 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siem Reap City Angkor Boutique",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.1",
#   "number_of_reviews": "50",
#   "price_usd_total": "38",
#   "room_type_or_description": "Deluxe King Room With Cantilevered Balcony",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 6 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Shadow Angkor Residence",
#   "distance_miles": "0.104",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "32",
#   "price_usd_total": "50",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 7 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Shalima Guesthouse",
#   "distance_miles": "0.11",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "39",
#   "room_type_or_description": "Deluxe Room with River View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 8 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Happy Zone Hostel",
#   "distance_miles": "0.113636",
#   "guest_rating_out_of_10": "3.7",
#   "number_of_reviews": "8",
#   "price_usd_total": "36",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 9 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Khmer Mansion Boutique Hotel",
#   "distance_miles": "650",
#   "guest_rating_out_of_10": "4.8",
#   "number_of_reviews": "43",
#   "price_usd_total": "15",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 10 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Uncle Sam Villa",
#   "distance_miles": "0.14",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "49",
#   "price_usd_total": "64",
#   "room_type_or_description": "Apsara Pool View twin Room Non smoking",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 11 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Reaksmey Chanreas Hotel",
#   "distance_miles": "0.14",
#   "guest_rating_out_of_10": "3.9",
#   "number_of_reviews": "34",
#   "price_usd_total": "20",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 12 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Ta Prohm Hotel & Spa",
#   "distance_miles": "0.15",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "57",
#   "price_usd_total": "19",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 13 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Summer Bliss Boutique",
#   "distance_miles": "0.15",
#   "guest_rating_out_of_10": "3.7",
#   "number_of_reviews": "5",
#   "price_usd_total": "39",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 14 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Apsara Centrepole Hotel",
#   "distance_miles": "0.16",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "37",
#   "price_usd_total": "24",
#   "room_type_or_description": "City Double Room, 1 King Bed, Balcony, City View",
#   "amenities": ["Free Cancellation", "Silver Member Price"]
# }
# ```
#
#
# 🔹 Hotel Block 15 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Aborest Tropical Hostel",
#   "distance_miles": "850",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "38",
#   "price_usd_total": "25",
#   "room_type_or_description": "Apsara Twin Studio with Balcony",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 16 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Ibis Styles Siem Reap",
#   "distance_miles": "0.16",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "47",
#   "price_usd_total": "33",
#   "room_type_or_description": "Private Dorm 4 Beds With Shared Bathrooms",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 17 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Bakong Hotel",
#   "distance_miles": "0.17",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "17",
#   "price_usd_total": "36",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 18 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Central Suite Residence",
#   "distance_miles": "0.18",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "51",
#   "price_usd_total": "20",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["Free Cancellation", "Silver Tier Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 19 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Le Water Villa",
#   "distance_miles": "0.18",
#   "guest_rating_out_of_10": "4.1",
#   "number_of_reviews": "28",
#   "price_usd_total": "53",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 20 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Koulen Central Hotel",
#   "distance_miles": "0.18",
#   "guest_rating_out_of_10": "9.2",
#   "number_of_reviews": "51",
#   "price_usd_total": "16",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 21 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Dusit Hotel Siem Reap",
#   "distance_miles": "0.18",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "29",
#   "price_usd_total": "59",
#   "room_type_or_description": "Standard Twin Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 22 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Glow Inn Siem Reap",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.2",
#   "number_of_reviews": "34",
#   "price_usd_total": "19",
#   "room_type_or_description": "Studio Twin Room - Free Pick Up",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 23 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siem Reap Urban Boutique Hotel",
#   "distance_miles": "0.2",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "39",
#   "price_usd_total": "31",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 24 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Blanc Smith Residence",
#   "distance_miles": "0.2",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "40",
#   "price_usd_total": "18",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 25 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Onederz Siem Reap",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.8",
#   "number_of_reviews": "42",
#   "price_usd_total": "46",
#   "room_type_or_description": "Classic Room With City View",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 26 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Le Vert Angkor Hotel",
#   "distance_miles": "0.2",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "58",
#   "price_usd_total": "30",
#   "room_type_or_description": "Standard Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 27 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor indian hotel",
#   "distance_miles": "0.21",
#   "guest_rating_out_of_10": "6.0",
#   "number_of_reviews": "4",
#   "price_usd_total": "34",
#   "room_type_or_description": "Deluxe Double With Balcony, City View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 28 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Apsara Residence Hotel",
#   "distance_miles": "0.21",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "81",
#   "price_usd_total": "12",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 29 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Rithy Rine Angkor Residence",
#   "distance_miles": "0.21",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "19",
#   "price_usd_total": "43",
#   "room_type_or_description": "Deluxe Twin Room with Balcony",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 30 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Two Seasons Siem Reap Hotel",
#   "distance_miles": "0.21",
#   "guest_rating_out_of_10": "9.2",
#   "number_of_reviews": "65",
#   "price_usd_total": "30",
#   "room_type_or_description": "Deluxe Double with City View Non smoking",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 31 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Chhay Long Angkor Boutique Hotel Siem Reap",
#   "distance_miles": "0.21",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "129",
#   "price_usd_total": "49",
#   "room_type_or_description": "Deluxe Double - City View",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 32 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Treeline Urban Resort",
#   "distance_miles": "0.22",
#   "guest_rating_out_of_10": "4.8",
#   "number_of_reviews": "52",
#   "price_usd_total": "31",
#   "room_type_or_description": "Deluxe King Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 33 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Aviary Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "70",
#   "price_usd_total": "222",
#   "room_type_or_description": "Deluxe Urban Twin Room",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 34 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cheathata Cta Hotel Siem Reap",
#   "distance_miles": "0.22",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "21",
#   "price_usd_total": "91",
#   "room_type_or_description": "Tailorbird Standard Twin Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 35 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Lotus Haven Villa",
#   "distance_miles": "0.227",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "7",
#   "price_usd_total": "23",
#   "room_type_or_description": "Deluxe Twin Room With Balcony",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 36 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cheathata Cts Hotel Siem Reap",
#   "distance_miles": "0.23",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "29",
#   "price_usd_total": "41",
#   "room_type_or_description": "Deluxe King Double Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 37 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Royal Crown Hotel & Spa",
#   "distance_miles": "0.227",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "73",
#   "price_usd_total": "33",
#   "room_type_or_description": "Studio Double",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 38 - Raw AI Output:
# ```json
# {
#   "hotel_name": "HOMEWOOD HOTEL",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "61",
#   "price_usd_total": "35",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 39 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Temple Boutique",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.9",
#   "number_of_reviews": "138",
#   "price_usd_total": "28",
#   "room_type_or_description": "Classic Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 40 - Raw AI Output:
# ```json
# {
#   "hotel_name": "KALINGA ART HOME GUESTHOUSEE",
#   "distance_miles": "1200",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "6",
#   "price_usd_total": "68",
#   "room_type_or_description": "Deluxe Suite -Free USD20.00 Credit on Spa",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 41 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Nico’s Hotel and SkyBar",
#   "distance_miles": "1250",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "38",
#   "price_usd_total": "14",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 42 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Udom Guesthouse",
#   "distance_miles": "0.24",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "2",
#   "price_usd_total": "21",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 43 - Raw AI Output:
# ```json
# {
#   "hotel_name": "City River Hotel",
#   "distance_miles": "0.24",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "21",
#   "price_usd_total": "61",
#   "room_type_or_description": "Deluxe Double Bed Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 44 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Temple Residence",
#   "distance_miles": "0.25",
#   "guest_rating_out_of_10": "9.6",
#   "number_of_reviews": "57",
#   "price_usd_total": "43",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 45 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Suite by Royal Crown Hotel",
#   "distance_miles": "1300",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "43",
#   "price_usd_total": "74",
#   "room_type_or_description": "Deluxe Suite - Free USD20.00 Credit on Spa",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 46 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Royal Crown Suite",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "58",
#   "room_type_or_description": "N/A",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 47 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Park Hyatt Siem Reap",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "45",
#   "price_usd_total": "36",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 48 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Urban Residences - Siem Reap",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "10.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "209",
#   "room_type_or_description": "2 Twin Beds",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 49 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Passport Villa",
#   "distance_miles": "0.255",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "2",
#   "price_usd_total": "136",
#   "room_type_or_description": "Apartment",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 50 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Twizt - Lifestyle Hostel & Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "116",
#   "price_usd_total": "23",
#   "room_type_or_description": "Economy Double Room",
#   "amenities": ["Free Cancellation", "Silver Member Price"]
# }
# ```
#
#
# 🔹 Hotel Block 51 - Raw AI Output:
# ```json
# {
#   "hotel_name": "MarvelInn Siem Reap",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "7",
#   "price_usd_total": "16",
#   "room_type_or_description": "Twin Room with Shared Bathroom",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 52 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Villa Wat Damnak",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "25",
#   "price_usd_total": "32",
#   "room_type_or_description": "Premier Double Apartment",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 53 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Bodee Corner Hotel",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "22",
#   "price_usd_total": "25",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 54 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Viroth's Villa",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "9.6",
#   "number_of_reviews": "55",
#   "price_usd_total": "21",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 55 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Bou Phanith Villa",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "41",
#   "price_usd_total": "84",
#   "room_type_or_description": "Deluxe Double or Twin Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 56 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Five Senses Boutique Hotel",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "36",
#   "price_usd_total": "14",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 57 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Center Point",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "34",
#   "price_usd_total": "29",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 58 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Naga Angkor Hostel",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "14",
#   "price_usd_total": "17",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 59 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Solitaire Damnak Villa Hotel",
#   "distance_miles": "0.27",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "45",
#   "price_usd_total": "16",
#   "room_type_or_description": "Superior Room",
#   "amenities": ["Free Cancellation", "Silver Member Price"]
# }
# ```
#
#
# 🔹 Hotel Block 60 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Rabbit Hole Hotel & Spa",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "3.8",
#   "number_of_reviews": "64",
#   "price_usd_total": "31",
#   "room_type_or_description": "Deluxe King Bed Suite",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 61 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Residence Wat Damnak",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "14",
#   "price_usd_total": "20",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 62 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Unique Angkor Villa",
#   "distance_miles": "0.26",
#   "guest_rating_out_of_10": "3.4",
#   "number_of_reviews": "16",
#   "price_usd_total": "28",
#   "room_type_or_description": "Deluxe Twin Room, 1 Bedroom, Balcony, Pool View",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 63 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Rambutan Resort – Siem Reap",
#   "distance_miles": "0.27",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "43",
#   "price_usd_total": "22",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 64 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Village Hotel - Small Luxury Hotels of the World",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "43",
#   "price_usd_total": "62",
#   "room_type_or_description": "Balcony Double Villa",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 65 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siem Reap Pub Hostel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.2",
#   "number_of_reviews": "71",
#   "price_usd_total": "153",
#   "room_type_or_description": "Garden View Double Room",
#   "amenities": ["Breakfast included", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 66 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Baahu Villa",
#   "distance_miles": "0.27",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "119",
#   "price_usd_total": "16",
#   "room_type_or_description": "Standard Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 67 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Maison 557",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "48",
#   "price_usd_total": "22",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 68 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Archaic House",
#   "distance_miles": "0.27",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "31",
#   "price_usd_total": "35",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 69 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Mony Reach Angkor Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "131",
#   "price_usd_total": "12",
#   "room_type_or_description": "Budget Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 70 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Tropical Breeze",
#   "distance_miles": "0.28",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "18",
#   "price_usd_total": "41",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 71 - Raw AI Output:
# ```json
# {
#   "hotel_name": "La Rivière d' Angkor Resort",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "42",
#   "price_usd_total": "14",
#   "room_type_or_description": "Double Room with Fan Non smoking",
#   "amenities": ["Free Cancellation", "Silver Tier Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 72 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Queentown Hostel",
#   "distance_miles": "0.29",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "151",
#   "room_type_or_description": "Garden View Suite Villa",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 73 - Raw AI Output:
# ```json
# {
#   "hotel_name": "King Rock Boutique Hotel",
#   "distance_miles": "0.29",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "47",
#   "price_usd_total": "27",
#   "room_type_or_description": "Standard Twin Room With City View",
#   "amenities": ["Free Cancellation", "Silver Member Price"]
# }
# ```
#
#
# 🔹 Hotel Block 74 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Lub d Cambodia Siem Reap",
#   "distance_miles": "0.29",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "161",
#   "price_usd_total": "39",
#   "room_type_or_description": "Deluxe King Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 75 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siem Reap Comfort Boutique",
#   "distance_miles": "0.29",
#   "guest_rating_out_of_10": "3.7",
#   "number_of_reviews": "10",
#   "price_usd_total": "23",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 76 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Banana Residence",
#   "distance_miles": "0.29",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "17",
#   "price_usd_total": "26",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 77 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siem Reap Comforts Hostel",
#   "distance_miles": "0.29",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "16",
#   "price_usd_total": "47",
#   "room_type_or_description": "Deluxe Double Room With Pool View And Balcony",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 78 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Pierre Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "9",
#   "price_usd_total": "19",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 79 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Butterfly Villa",
#   "distance_miles": "1600",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "89",
#   "price_usd_total": "58",
#   "room_type_or_description": "Deluxe Double City View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 80 - Raw AI Output:
# ```json
# {
#   "hotel_name": "King Rock Residence",
#   "distance_miles": "0.3",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "37",
#   "price_usd_total": "18",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 81 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Central Night Hotel",
#   "distance_miles": "1600",
#   "guest_rating_out_of_10": "4.0",
#   "number_of_reviews": "11",
#   "price_usd_total": "34",
#   "room_type_or_description": "Luxury Deluxe King Room",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 82 - Raw AI Output:
# ```json
# {
#   "hotel_name": "N/A",
#   "distance_miles": "0.303",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "7",
#   "price_usd_total": "17",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 83 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Damnak Riverside Villa",
#   "distance_miles": "0.30",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "54",
#   "room_type_or_description": "Superior Room, 1 Bedroom, Non Smoking",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 84 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Aurora",
#   "distance_miles": "0.31",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "126",
#   "price_usd_total": "94",
#   "room_type_or_description": "Standard Double Room With AC",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 85 - Raw AI Output:
# ```json
# {
#   "hotel_name": "King Boutique Hotel",
#   "distance_miles": "0.31",
#   "guest_rating_out_of_10": "3.1",
#   "number_of_reviews": "41",
#   "price_usd_total": "40",
#   "room_type_or_description": "Premier Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 86 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Viroth's Hotel",
#   "distance_miles": "0.31",
#   "guest_rating_out_of_10": "4.9",
#   "number_of_reviews": "93",
#   "price_usd_total": "12",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 87 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Beyond Yangon Inn",
#   "distance_miles": "0.32",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "15",
#   "price_usd_total": "125",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 88 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Leap Hotel",
#   "distance_miles": "0.32",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "6",
#   "price_usd_total": "36",
#   "room_type_or_description": "Ground Floor Queen Room",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 89 - Raw AI Output:
# ```json
# {
#   "hotel_name": "SIEM REAP RIVER VIEW RESIDENCE",
#   "distance_miles": "0.32",
#   "guest_rating_out_of_10": "4.2",
#   "number_of_reviews": "1",
#   "price_usd_total": "22",
#   "room_type_or_description": "Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 90 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Privilege Boutique",
#   "distance_miles": "0.33",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "14",
#   "price_usd_total": "57",
#   "room_type_or_description": "Deluxe City View Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 91 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Somadevi Angkor Boutique and Resort",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "62",
#   "price_usd_total": "63",
#   "room_type_or_description": "Cabana Twin Room",
#   "amenities": ["Free Cancellation", "First Booking Deal", "10% Off"]
# }
# ```
#
#
# 🔹 Hotel Block 92 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Temple Hotel",
#   "distance_miles": "0.33",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "67",
#   "price_usd_total": "61",
#   "room_type_or_description": "Executive Deluxe King Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 93 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Somadevi Residence",
#   "distance_miles": "0.33",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "59",
#   "price_usd_total": "49",
#   "room_type_or_description": "Superior King Room Non smoking - Free USD15 Credit on Spa",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 94 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Channary Hotel",
#   "distance_miles": "0.33",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "1",
#   "price_usd_total": "67",
#   "room_type_or_description": "Deluxe Double Room Pool View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 95 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Noni Tree Hostel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "21",
#   "price_usd_total": "26",
#   "room_type_or_description": "Standard Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 96 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Mansion & Residence",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "8",
#   "price_usd_total": "25",
#   "room_type_or_description": "Deluxe Double Room With Balcony",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 97 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Den Hotel Totonou Siem Reap",
#   "distance_miles": "0.33",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "56",
#   "price_usd_total": "34",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 98 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Place Hostel Siem Reap Angkor",
#   "distance_miles": "0.33",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "8",
#   "price_usd_total": "17",
#   "room_type_or_description": "Economy Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 99 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Somadevi Angkor Premium",
#   "distance_miles": "0.34",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "39",
#   "price_usd_total": "23",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation", "Silver Member Price"]
# }
# ```
#
#
# 🔹 Hotel Block 100 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Monthara Angkor Residence",
#   "distance_miles": "0.34",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "26",
#   "price_usd_total": "35",
#   "room_type_or_description": "Superior Twin Room - Room Only",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 101 - Raw AI Output:
# ```json
# {
#   "hotel_name": "La Villa du Bonheur",
#   "distance_miles": "0.34",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "3",
#   "price_usd_total": "34",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 102 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Tito Suite Residence",
#   "distance_miles": "0.35",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "49",
#   "price_usd_total": "43",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 103 - Raw AI Output:
# ```json
# {
#   "hotel_name": "LA PLANTE SIEM REAP",
#   "distance_miles": "0.35",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "5",
#   "price_usd_total": "33",
#   "room_type_or_description": "Deluxe Double Room With Pool View Non Smoking",
#   "amenities": ["Free Cancellation", "Pool View"]
# }
# ```
#
#
# 🔹 Hotel Block 104 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The One by Nika",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "10",
#   "price_usd_total": "77",
#   "room_type_or_description": "Deluxe Room",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 105 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Somadevi Angkor Resort & Spa",
#   "distance_miles": "0.35",
#   "guest_rating_out_of_10": "9.2",
#   "number_of_reviews": "238",
#   "price_usd_total": "21",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["Free Cancellation", "Great swimming pool", "Delicious breakfast"]
# }
# ```
#
#
# 🔹 Hotel Block 106 - Raw AI Output:
# ```json
# {
#   "hotel_name": "BB Angkor Residence",
#   "distance_miles": "0.35",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "14",
#   "price_usd_total": "31",
#   "room_type_or_description": "Superior Twin With Balcony - No Breakfast",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 107 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hari Residence & Spa",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "40",
#   "price_usd_total": "37",
#   "room_type_or_description": "King Suite with Balcony",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 108 - Raw AI Output:
# ```json
# {
#   "hotel_name": "BayStone Resort",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "16",
#   "price_usd_total": "49",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 109 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Rithy Rin Angkor Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "20",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 110 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Garden Village Guesthouse & Pool Bar",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "45",
#   "price_usd_total": "26",
#   "room_type_or_description": "Deluxe Double Pool View",
#   "amenities": ["Free Cancellation", "Early Bird Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 111 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Home Inn",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "10.0",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "8",
#   "room_type_or_description": "Budget Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 112 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Parent Heritage Angkor Villa",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "6",
#   "price_usd_total": "26",
#   "room_type_or_description": "Standard Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 113 - Raw AI Output:
# ```json
# {
#   "hotel_name": "SK Residence",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "2",
#   "price_usd_total": "23",
#   "room_type_or_description": "Standard Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 114 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Luxury",
#   "distance_miles": "0.37",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "10",
#   "price_usd_total": "150",
#   "room_type_or_description": "Deluxe King Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 115 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siem Reap Palace Hotel & Spa",
#   "distance_miles": "0.37",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "66",
#   "price_usd_total": "24",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 116 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel la Maravilla",
#   "distance_miles": "0.37",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "86",
#   "price_usd_total": "50",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 117 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Bayon Boutique Hotel",
#   "distance_miles": "0.37",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "28",
#   "room_type_or_description": "Standard Double Room",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 118 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Jungle",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "34",
#   "price_usd_total": "25",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 119 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Riverside Boutique Resort & Spa, Siem Reap",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "2",
#   "price_usd_total": "59",
#   "room_type_or_description": "Deluxe Family Room With Garden View",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 120 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Funky Village",
#   "distance_miles": "0.38",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "68",
#   "price_usd_total": "57",
#   "room_type_or_description": "Double Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 121 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Mekong Angkor Palace Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "37",
#   "price_usd_total": "13",
#   "room_type_or_description": "Private Dorm-Sleeps 2 Shared Bathroom",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 122 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Shinta Mani Angkor",
#   "distance_miles": "0.38",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "65",
#   "price_usd_total": "28",
#   "room_type_or_description": "Superior Triple Room with Balcony",
#   "amenities": ["Free Cancellation", "Silver Member Price"]
# }
# ```
#
#
# 🔹 Hotel Block 123 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Riversoul Boutique",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "87",
#   "price_usd_total": "156",
#   "room_type_or_description": "Bayon King Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 124 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Chateau d'Angkor La Residence",
#   "distance_miles": "0.39",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "55",
#   "price_usd_total": "35",
#   "room_type_or_description": "Deluxe King Room with Pool View",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 125 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Temple Retreat",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "9.6",
#   "number_of_reviews": "60",
#   "price_usd_total": "100",
#   "room_type_or_description": "One Bedroom Suite",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 126 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Orchid Angkor",
#   "distance_miles": "0.4",
#   "guest_rating_out_of_10": "3.8",
#   "number_of_reviews": "5",
#   "price_usd_total": "58",
#   "room_type_or_description": "Premier Suite Twin Pool View - Free USD15 Spa Credit",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 127 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Side Walk Hotel",
#   "distance_miles": "0.4",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "42",
#   "price_usd_total": "22",
#   "room_type_or_description": "Superior Double Room Non smoking",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 128 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Khmer House Boutique",
#   "distance_miles": "2150",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "42",
#   "price_usd_total": "15",
#   "room_type_or_description": "Double Room with Fan",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 129 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Villa Um Theara, Siem Reap",
#   "distance_miles": "0.41",
#   "guest_rating_out_of_10": "7.2",
#   "number_of_reviews": "16",
#   "price_usd_total": "40",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 130 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sakaban Suite",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "54",
#   "price_usd_total": "30",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 131 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Aroma Angkor Boutique Hotel",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "3",
#   "price_usd_total": "40",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 132 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Blossoming Romduol Boutique",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "39",
#   "price_usd_total": "56",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 133 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Prince Angkor Hotel & Spa",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "161",
#   "price_usd_total": "26",
#   "room_type_or_description": "Twin Room With Air Conditioner",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 134 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Central Corner d'Angkor",
#   "distance_miles": "0.43",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "95",
#   "price_usd_total": "49",
#   "room_type_or_description": "Superior King Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 135 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siem Reap Center Hotel",
#   "distance_miles": "0.43",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "14",
#   "price_usd_total": "21",
#   "room_type_or_description": "Studio Double Room with Pool View and Balcony",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 136 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Amber Angkor Villa Hotel & Spa",
#   "distance_miles": "0.43",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "62",
#   "price_usd_total": "21",
#   "room_type_or_description": "Double Or Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 137 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Cockatoo Nature Resort & Spa",
#   "distance_miles": "0.43",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "19",
#   "price_usd_total": "28",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 138 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Le Grande Indochine Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "27",
#   "room_type_or_description": "Deluxe Double With Garden View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 139 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sakaban Suite",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "28",
#   "room_type_or_description": "Deluxe Double Or Twin",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 140 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Chhouy Vathna Angkor Boutique",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "5",
#   "price_usd_total": "38",
#   "room_type_or_description": "Deluxe Double Room, 1 Bedroom, Balcony, Pool View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 141 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Central Corner Suite",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "19",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 142 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Lavender Angkor Boutique",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "4.2",
#   "number_of_reviews": "19",
#   "price_usd_total": "53",
#   "room_type_or_description": "Studio with Pool View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 143 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Easy Go Home",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "3.3",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "31",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Free Cancellation", "Early Bird Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 144 - Raw AI Output:
# ```json
# {
#   "hotel_name": "La Niche d'Angkor Boutique Hotel",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "36",
#   "price_usd_total": "27",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 145 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Blanc Residence",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "16",
#   "price_usd_total": "45",
#   "room_type_or_description": "Deluxe Double Room with Pool View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 146 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Phka Chan Hotel",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "79",
#   "price_usd_total": "27",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 147 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sam So Guesthouse",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "7",
#   "price_usd_total": "42",
#   "room_type_or_description": "Deluxe Double with Balcony",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 148 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Grand Bayon Siem Reap Hotel",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "36",
#   "price_usd_total": "18",
#   "room_type_or_description": "Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 149 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Moon Residence & Spa",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "63",
#   "price_usd_total": "44",
#   "room_type_or_description": "Deluxe Twin Room with City View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 150 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Central Indochine d'Angkor Hotel",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "46",
#   "price_usd_total": "23",
#   "room_type_or_description": "Deluxe Double Room With Pool View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 151 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Central Privilege Hotel",
#   "distance_miles": "0.46",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "22",
#   "price_usd_total": "18",
#   "room_type_or_description": "Deluxe Double Or Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 152 - Raw AI Output:
# ```json
# {
# ...
# }
# ```
#
#
# 🔹 Hotel Block 274 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sokchea Angkor Hotel",
#   "distance_miles": "0.91",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "52",
#   "price_usd_total": "64",
#   "room_type_or_description": "Double Bed Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 275 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Isann Villa",
#   "distance_miles": "0.91",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "39",
#   "room_type_or_description": "Deluxe King Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 276 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Mera Residence",
#   "distance_miles": "0.91",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "17",
#   "price_usd_total": "93",
#   "room_type_or_description": "Rustic 1960s Wooden Villa With Swimming Pool",
#   "amenities": ["Free Cancellation", "Swimming Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 277 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Blanc Smith Hotel",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "33",
#   "price_usd_total": "29",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 278 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cambana d'Angkor Suites",
#   "distance_miles": "0.92",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "60",
#   "price_usd_total": "37",
#   "room_type_or_description": "Superior Twin Room",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 279 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Authentic Khmer Village Resort",
#   "distance_miles": "0.93",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "63",
#   "price_usd_total": "35",
#   "room_type_or_description": "Deluxe Double Suite Private Balcony",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 280 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Sweet Night Hotel",
#   "distance_miles": "0.93",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "17",
#   "price_usd_total": "79",
#   "room_type_or_description": "Traditional House with Terrace",
#   "amenities": ["Breakfast included", "Terrace"]
# }
# ```
#
#
# 🔹 Hotel Block 281 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Tempora Boutique",
#   "distance_miles": "0.93",
#   "guest_rating_out_of_10": "9.2",
#   "number_of_reviews": "60",
#   "price_usd_total": "28",
#   "room_type_or_description": "Deluxe King Private Balcony, Pool View",
#   "amenities": ["Free Cancellation", "Great swimming pool", "Quiet & comfortable"]
# }
# ```
#
#
# 🔹 Hotel Block 282 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Plumeria Hotel & Spa",
#   "distance_miles": "0.96",
#   "guest_rating_out_of_10": "3.8",
#   "number_of_reviews": "11",
#   "price_usd_total": "26",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 283 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Siemreap City Residence",
#   "distance_miles": "0.96",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "4",
#   "price_usd_total": "23",
#   "room_type_or_description": "Superior Double Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 284 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Apsara Greenland Boutique Villa",
#   "distance_miles": "0.97",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "19",
#   "price_usd_total": "37",
#   "room_type_or_description": "Deluxe King Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 285 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Maison Polanka",
#   "distance_miles": "0.97",
#   "guest_rating_out_of_10": "10.0",
#   "number_of_reviews": "33",
#   "price_usd_total": "30",
#   "room_type_or_description": "Deluxe Double Room with Balcony",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 286 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Eightfold Urban Resort",
#   "distance_miles": "0.97",
#   "guest_rating_out_of_10": "4.8",
#   "number_of_reviews": "48",
#   "price_usd_total": "298",
#   "room_type_or_description": "Green or Yellow Suite",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 287 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Natural Relax Villa",
#   "distance_miles": "0.97",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "4",
#   "price_usd_total": "67",
#   "room_type_or_description": "Double Or Twin Room With Pool View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 288 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Old Khmer House",
#   "distance_miles": "5150",
#   "guest_rating_out_of_10": "4.9",
#   "number_of_reviews": "3",
#   "price_usd_total": "34",
#   "room_type_or_description": "Deluxe Double Room With Balcony And Pool View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 289 - Raw AI Output:
# ```json
# {
#   "hotel_name": "My Key Polanka Pirvate Villa with Pool",
#   "distance_miles": "0.98",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "1",
#   "price_usd_total": "25",
#   "room_type_or_description": "Boutique Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 290 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Le Chanthou Boutique",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "27",
#   "price_usd_total": "328",
#   "room_type_or_description": "Entire unit 200㎡· 4 bedrooms· 7 beds",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 291 - Raw AI Output:
# ```json
# {
#   "hotel_name": "LY Residence Suite & Apartment",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "59",
#   "room_type_or_description": "Premier Suite",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 292 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Bunwin Siem Reap",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "14",
#   "price_usd_total": "72",
#   "room_type_or_description": "One Bed Room Residence Suite",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 293 - Raw AI Output:
# ```json
# {
#   "hotel_name": "YASODHARAPURA RESIDENCE",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "34",
#   "price_usd_total": "112",
#   "room_type_or_description": "Suite with Pool View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 294 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Khemara Angkor Hotel & Spa",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "19",
#   "price_usd_total": "28",
#   "room_type_or_description": "Deluxe Twin Room Garden View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 295 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Waka Villa Private Resort & Spa - Adults Only",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.9",
#   "number_of_reviews": "56",
#   "price_usd_total": "36",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 296 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Heart Bungalow",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.8",
#   "number_of_reviews": "68",
#   "price_usd_total": "240",
#   "room_type_or_description": "Private Pool Villa - 1 Bedroom",
#   "amenities": ["Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 297 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Baray Siem Reap House",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "76",
#   "room_type_or_description": "Deluxe Triple Bungalow",
#   "amenities": ["Free Cancellation", "Silver Member Price"]
# }
# ```
#
#
# 🔹 Hotel Block 298 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Savada Angkor Boutique Hotel",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "4",
#   "price_usd_total": "86",
#   "room_type_or_description": "Basic Apartment, 1 King Bed, Non Smoking",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 299 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cambana Residence",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "35",
#   "price_usd_total": "39",
#   "room_type_or_description": "Deluxe Twin Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 300 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Phum Khmer Lodge - Village Cambodian Eco-Lodge",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "41",
#   "price_usd_total": "35",
#   "room_type_or_description": "Deluxe King Suite with Balcony",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 301 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Khemara Siem Reap Hotel",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.9",
#   "number_of_reviews": "14",
#   "price_usd_total": "374",
#   "room_type_or_description": "Suite With Pool View",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 302 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Tanei Angkor Resort and Spa",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "56",
#   "price_usd_total": "35",
#   "room_type_or_description": "Deluxe Double Or Twin Room",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 303 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Vishnu Villa",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "5",
#   "price_usd_total": "34",
#   "room_type_or_description": "Deluxe Double or Twin with Balcony",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 304 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Green Amazon Residence Hotel",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "69",
#   "price_usd_total": "172",
#   "room_type_or_description": "Spacious 3 Bedroom Villa with Garden View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 305 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Golden Citadel Hotel Siem Reap",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.3",
#   "number_of_reviews": "4",
#   "price_usd_total": "31",
#   "room_type_or_description": "Deluxe King Balcony",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 306 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Memoire Palace Resort & Spa",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "42",
#   "price_usd_total": "24",
#   "room_type_or_description": "Deluxe Double Room with Balcony",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 307 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Villa Indochine d'Angkor",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "17",
#   "price_usd_total": "72",
#   "room_type_or_description": "Junior Garden Suite Non Smoking",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 308 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Ptas Songsaa By Amatak",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "19",
#   "room_type_or_description": "Deluxe Double Or Twin Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 309 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Royal Family Suite by Memoire Palace Resort & Spa",
#   "distance_miles": "1",
#   "guest_rating_out_of_10": "4.8",
#   "number_of_reviews": "32",
#   "price_usd_total": "765",
#   "room_type_or_description": "Deluxe Room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 310 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Style Resort",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "4.9",
#   "number_of_reviews": "4",
#   "price_usd_total": "84",
#   "room_type_or_description": "Luxury Grand Garden Suite",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 311 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Koki Tree",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "10.0",
#   "number_of_reviews": "2",
#   "price_usd_total": "33",
#   "room_type_or_description": "Deluxe Double room",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 312 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Khemara Sovannphum Hotel",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "4.1",
#   "number_of_reviews": "7",
#   "price_usd_total": "60",
#   "room_type_or_description": "Double Or Twin Room With Pool View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 313 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Residence Indochine d'Angkor",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "4.5",
#   "number_of_reviews": "54",
#   "price_usd_total": "137",
#   "room_type_or_description": "Deluxe Double Room",
#   "amenities": ["Free Cancellation", "Breakfast included", "First Booking Deal", "10% Off"]
# }
# ```
#
#
# 🔹 Hotel Block 314 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Seyna Residence",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "5.0",
#   "number_of_reviews": "2",
#   "price_usd_total": "23",
#   "room_type_or_description": "Twin Cabana Room with Balcony and Pool View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 315 - Raw AI Output:
# ```json
# {
#   "hotel_name": "P5 Angkor Residence",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "4.1",
#   "number_of_reviews": "10",
#   "price_usd_total": "43",
#   "room_type_or_description": "Deluxe Suite",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 316 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Khmer House Resort",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "42",
#   "price_usd_total": "21",
#   "room_type_or_description": "Double Room",
#   "amenities": ["Free Cancellation", "Special Discount"]
# }
# ```
#
#
# 🔹 Hotel Block 317 - Raw AI Output:
# ```json
# {
#   "hotel_name": "SANNA VILLA Residence",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "6",
#   "price_usd_total": "37",
#   "room_type_or_description": "Khmer Style Superior Double Room",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 318 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Starry Angkor Hotel",
#   "distance_miles": "1.1",
#   "guest_rating_out_of_10": "4.0",
#   "number_of_reviews": "6",
#   "price_usd_total": "71",
#   "room_type_or_description": "One Bedroom Villa King Size Bed Balcony Pool View",
#   "amenities": ["Free Cancellation", "Early Bird Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 319 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Elysium Suite",
#   "distance_miles": "1.2",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "108",
#   "price_usd_total": "30",
#   "room_type_or_description": "Superior Double Or Twin Room With City View",
#   "amenities": ["Free Cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 320 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Angkor Rithy Residence",
#   "distance_miles": "1.2",
#   "guest_rating_out_of_10": "4.0",
#   "number_of_reviews": "49",
#   "price_usd_total": "35",
#   "room_type_or_description": "Cabana Room with Pool Access",
#   "amenities": ["Free Cancellation", "Breakfast included"]
# }
# ```
#
#
# 🔹 Hotel Block 321 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Saem Siemreap Hotel",
#   "distance_miles": "1.2",
#   "guest_rating_out_of_10": "4.7",
#   "number_of_reviews": "116",
#   "price_usd_total": "26",
#   "room_type_or_description": "Soupier Room With Hot Tub",
#   "amenities": ["Free Cancellation", "First Booking Deal"]
# }
# ```
#
#
# 🔹 Hotel Block 322 - Raw AI Output:
# ```json
# {
#   "hotel_name": "N/A",
#   "distance_miles": "N/A",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "59",
#   "room_type_or_description": "Deluxe Room, Breakfast included",
#   "amenities": []
# }
# ```

# %%
df_trip_structured = df_trip_structured[df_trip_structured["price_usd_total"] != "N/A"].reset_index(drop=True)
df_trip_structured
# Out:
#                          hotel_name distance_miles guest_rating_out_of_10  \
# 0               Neth Socheata Hotel          0.076                    8.4
# 1                 The Atelier Hotel          0.085                    4.1
# 2    Siem Reap City Angkor Boutique            N/A                    4.1
# 3           Shadow Angkor Residence          0.104                    9.0
# 4                Shalima Guesthouse           0.11                    7.0
# ..                              ...            ...                    ...
# 314             Starry Angkor Hotel            1.1                    4.0
# 315                   Elysium Suite            1.2                    4.7
# 316          Angkor Rithy Residence            1.2                    4.0
# 317             Saem Siemreap Hotel            1.2                    4.7
# 318                             N/A            N/A                    N/A
#
#     number_of_reviews price_usd_total  \
# 0                  29              49
# 1                  12              34
# 2                  50              38
# 3                  32              50
# 4                   1              39
# ..                ...             ...
# 314                 6              71
# 315               108              30
# 316                49              35
# 317               116              26
# 318               N/A              59
#
#                               room_type_or_description  \
# 0                                     Deluxe Twin Room
# 1                                   Deluxe Family Room
# 2           Deluxe King Room With Cantilevered Balcony
# 3                                 Superior Double Room
# 4                          Deluxe Room with River View
# ..                                                 ...
# 314  One Bedroom Villa King Size Bed Balcony Pool View
# 315        Superior Double Or Twin Room With City View
# 316                       Cabana Room with Pool Access
# 317                          Soupier Room With Hot Tub
# 318                    Deluxe Room, Breakfast included
#
#                                    amenities
# 0    [Free Cancellation, Breakfast included]
# 1      [Free Cancellation, Special Discount]
# 2                        [Free Cancellation]
# 3                        [Free Cancellation]
# 4                        [Free Cancellation]
# ..                                       ...
# 314     [Free Cancellation, Early Bird Deal]
# 315                      [Free Cancellation]
# 316  [Free Cancellation, Breakfast included]
# 317  [Free Cancellation, First Booking Deal]
# 318                                       []
#
# [319 rows x 7 columns]

# %%
df_trip_structured.to_excel('Trip.com_combodia.xlsx', index = False)
