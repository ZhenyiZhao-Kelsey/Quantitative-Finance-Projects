# %%
import re
import pandas as pd
from openai import OpenAI
import json
import ast

# %%
# Open and display the raw contents of the Osaka hotel search results file
file_path = "Rizal Park, Manila, National Capital Region, Philippines Hotel Search Results.txt"
with open(file_path, 'r', encoding='utf-8') as file:
    raw_text = file.read()

# Display the first 3000 characters of the raw text to give an overview
# raw_text[:3000]

# %%
# Split the text into chunks based on repeating "Photo gallery for" which marks the start of hotel listings
hotel_blocks = re.split(r'\n\s*Photo gallery for ', raw_text)

# Remove the first block which is navigation/menu before the listings
hotel_blocks = hotel_blocks[1:]

# Re-add the 'Photo gallery for' text to each block for clarity
hotel_blocks = ['Photo gallery for ' + block.strip() for block in hotel_blocks]

# Create a DataFrame where each row corresponds to one hotel listing block
df_blocks = pd.DataFrame(hotel_blocks, columns=["Hotel Block"])


df_blocks
# Out:
#                                            Hotel Block
# 0    Photo gallery for Maria Clara - Kalaw Ave · Fi...
# 1    Photo gallery for Ocean view studio room (1bed...
# 2    Photo gallery for Manila Chic London Street, c...
# 3    Photo gallery for City Garden Suites Manila\n\...
# 4    Photo gallery for Anex Hotel-Manila\n\nRecepti...
# ..                                                 ...
# 343  Photo gallery for Cozy Nook. Across Greenbelt5...
# 344  Photo gallery for 1 BR Fully Furnished Condo a...
# 345  Photo gallery for 1 BR Fully Furnished Condo i...
# 346  Photo gallery for The Sphere Serviced Residenc...
# 347  Photo gallery for Hotel 101 - Manila\n\nOutdoo...
#
# [348 rows x 1 columns]

# %%
# df_blocks.to_csv('df_blocks.csv',index = False)

# %%
api_key = 'sk-9c8a52fa5ba140608bb8484c3a27cffa'

# %%
hotel_blocks = df_blocks["Hotel Block"].tolist()

client = OpenAI(
    api_key= api_key,  # Your real key
    base_url="https://api.deepseek.com"
)

# Generalized, location-agnostic system prompt
system_prompt = (
    "You are processing a printed text block from an Expedia hotel search result page. "
    "Each block describes one or more hotels. Extract only visible hotel data, and return it as valid JSON.\n\n"
    "Each hotel must include:\n"
    "{\n"
    "  \"hotel_name\": \"\",\n"
    "  \"distance_miles\": \"\",            # Only the numeric value, e.g., \"0.4\". No units or locations.\n"
    "  \"guest_rating_out_of_10\": \"\",    # Only the numeric value, e.g., \"8.6\"\n"
    "  \"number_of_reviews\": \"\",         # Numeric only, e.g., \"1178\"\n"
    "  \"price_usd_total\": \"\",           # Only the number, e.g., \"85\". No '$', 'USD', or 'total'.\n"
    "  \"room_type_or_description\": \"\",\n"
    "  \"amenities\": [\"\", \"\"]          # List of amenities that are explicitly mentioned\n"
    "}\n\n"
    "Strict rules:\n"
    "- Do NOT include units, symbols, or extra words in numeric fields.\n"
    "- Do NOT guess. Use \"N/A\" if a field is not available.\n"
    "- Output must be a JSON object or list of objects. No markdown, code blocks, or comments."
)

results = []

for i, block in enumerate(hotel_blocks):
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": block}
        ],
        temperature=0.0,
        stream=False
    )

    raw_text = response.choices[0].message.content.strip()
    print(f"\n🔹 Hotel Block {i} - Raw AI Output:\n{raw_text}\n")

    # Clean formatting: strip ```json and ``` if present
    cleaned = raw_text.strip("` \n")
    if cleaned.startswith("json"):
        cleaned = cleaned[4:].strip()

    try:
        parsed = ast.literal_eval(cleaned)
        if isinstance(parsed, dict):
            results.append(parsed)
        elif isinstance(parsed, list):
            results.extend(parsed)
        else:
            raise ValueError("Parsed content is not a dict or list")
    except Exception as e:
        print(f"❌ Parse error on block {i}: {e}")
        results.append({
            "hotel_name": "ERROR",
            "distance_from_osaka_castle_mi": "ERROR",
            "guest_rating_out_of_10": "ERROR",
            "number_of_reviews": "ERROR",
            "price_usd_total": "ERROR",
            "room_type_or_description": "ERROR",
            "amenities": ["ERROR"]
        })

# Save to DataFrame
df_structured = pd.DataFrame(results)
print("\n✅ Final structured hotel DataFrame preview:\n")
print(df_structured.head())
# Out:
# 🔹 Hotel Block 0 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Maria Clara - Kalaw Ave · Filipino Themed Luxury 2BR W/Free Airport Pickup",
#   "distance_miles": "0.15",
#   "guest_rating_out_of_10": "9.8",
#   "number_of_reviews": "60",
#   "price_usd_total": "185",
#   "room_type_or_description": "Entire condo, Sleeps 6, 2 bedrooms, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 1 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Ocean view studio room (1bed)",
#   "distance_miles": "0.27",
#   "guest_rating_out_of_10": "2.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "87",
#   "room_type_or_description": "Entire apartment, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 2 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Chic London Street, coffee bar Oceanview",
#   "distance_miles": "0.27",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "130",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 3 - Raw AI Output:
# ```json
# {
#   "hotel_name": "City Garden Suites Manila",
#   "distance_miles": "0.29",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "1001",
#   "price_usd_total": "55",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 4 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Anex Hotel-Manila",
#   "distance_miles": "0.3",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "616",
#   "price_usd_total": "38",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 5 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Miramar Hotel",
#   "distance_miles": "0.3",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "188",
#   "price_usd_total": "40",
#   "room_type_or_description": "N/A",
#   "amenities": ["Terrace/patio"]
# }
# ```
#
#
# 🔹 Hotel Block 6 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Time Traveller's Hotel",
#   "distance_miles": "0.31",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "162",
#   "price_usd_total": "27",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 7 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Airo Hotel-Manila",
#   "distance_miles": "0.31",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "46",
#   "price_usd_total": "34",
#   "room_type_or_description": "N/A",
#   "amenities": ["Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 8 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Ralph Anthony Suites",
#   "distance_miles": "0.32",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "5",
#   "price_usd_total": "66",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 9 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Juliano By Zuzu",
#   "distance_miles": "0.35",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "26",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 10 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Serene & Luxurious 1BR Torre De Manila – Stunning Luneta Park & Intramuros Views",
#   "distance_miles": "0.35",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "123",
#   "room_type_or_description": "Entire condo, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Terrace/patio"]
# }
# ```
#
#
# 🔹 Hotel Block 11 - Raw AI Output:
# ```json
# {
#   "hotel_name": "2BR Gem in MNL w/Pool, Fast WiFi, Netflix Near Luneta US Embassy & Intramuros",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "91",
#   "room_type_or_description": "Entire condo",
#   "amenities": ["Pool", "Fast WiFi", "Netflix"]
# }
# ```
#
#
# 🔹 Hotel Block 12 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Charming 1-bedroom condo in marvelous Manila",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "62",
#   "room_type_or_description": "Entire condo",
#   "amenities": ["AC", "WiFi", "fitness room", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 13 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Manila Hotel",
#   "distance_miles": "0.36",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "996",
#   "price_usd_total": "134",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Hot tub"]
# }
# ```
#
#
# 🔹 Hotel Block 14 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Juliano",
#   "distance_miles": "0.38",
#   "guest_rating_out_of_10": "7.8",
#   "number_of_reviews": "75",
#   "price_usd_total": "26",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 15 - Raw AI Output:
# ```json
# {
#   "hotel_name": "OYO 858 City Stay Inns Bgc Nuevo",
#   "distance_miles": "0.39",
#   "guest_rating_out_of_10": "5.2",
#   "number_of_reviews": "13",
#   "price_usd_total": "21",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later"]
# }
# ```
#
#
# 🔹 Hotel Block 16 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Rizal Park Hotel",
#   "distance_miles": "0.39",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "456",
#   "price_usd_total": "79",
#   "room_type_or_description": "Garden view",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 17 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Red Planet Manila Bay",
#   "distance_miles": "0.4",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "831",
#   "price_usd_total": "36",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 18 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 Bedroom in 8 Adriatico Manila",
#   "distance_miles": "0.4",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "43",
#   "price_usd_total": "202",
#   "room_type_or_description": "Entire condo, Sleeps 2, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 19 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cozy 1-bedroom condo in Manila close to U.S Embassy and SLMEC",
#   "distance_miles": "0.4",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "3",
#   "price_usd_total": "133",
#   "room_type_or_description": "Entire condo, 1 bedroom, 1 bathroom",
#   "amenities": ["Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 20 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cozy 1-bedroom condo near UP Manila, US EMBASSY and St. Luke's Medical Center",
#   "distance_miles": "0.4",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "16",
#   "price_usd_total": "146",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Property grounds"]
# }
# ```
#
#
# 🔹 Hotel Block 21 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Chic condo in marvelous Manila with parking, fitness room, WiFi near US Embassy",
#   "distance_miles": "0.4",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "153",
#   "room_type_or_description": "Entire apartment, Sleeps 2, 1 bathroom",
#   "amenities": ["Pool", "Washer and dryer", "Parking", "Fitness room", "WiFi"]
# }
# ```
#
#
# 🔹 Hotel Block 22 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cozy condo in Manila near Supreme Court, UP-PGH, US Embassy, and ST. Lukes",
#   "distance_miles": "0.41",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "96",
#   "room_type_or_description": "Entire apartment",
#   "amenities": ["Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 23 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Stylish Contemporary studio @ 8adriatico condo + pool + NetFlix",
#   "distance_miles": "0.41",
#   "guest_rating_out_of_10": "9.6",
#   "number_of_reviews": "14",
#   "price_usd_total": "76",
#   "room_type_or_description": "Entire apartment, Sleeps 2, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 24 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Pearl Manila Hotel",
#   "distance_miles": "0.41",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "569",
#   "price_usd_total": "42",
#   "room_type_or_description": "N/A",
#   "amenities": ["Outdoor pool"]
# }
# ```
#
#
# 🔹 Hotel Block 25 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Lotus Hotel",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "717",
#   "price_usd_total": "38",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 26 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Embassy Waves Retreat",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "80",
#   "room_type_or_description": "Entire apartment, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Private kitchen", "Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 27 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Bay Sunset Apartment",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "85",
#   "room_type_or_description": "Entire apartment",
#   "amenities": ["Private kitchen", "Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 28 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Embassy Waves Retreat",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "96",
#   "room_type_or_description": "Entire apartment, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Private kitchen", "Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 29 - Raw AI Output:
# ```json
# {
#   "hotel_name": "European Style Sea View Apartment",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "153",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 30 - Raw AI Output:
# ```json
# {
#   "hotel_name": "日落大道马尼拉湾公馆",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "3",
#   "price_usd_total": "160",
#   "room_type_or_description": "Entire apartment, 2 bedrooms, 2 bathrooms",
#   "amenities": ["Private kitchen", "Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 31 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sunset Embassy Suites",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "4.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "182",
#   "room_type_or_description": "Entire apartment, Sleeps 6, 3 bedrooms, 2 bathrooms",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 32 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sunset Embassy Apartments",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "6.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "212",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Private kitchen", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 33 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Bay Embassy Ocean View Room",
#   "distance_miles": "0.42",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "75",
#   "room_type_or_description": "Entire condo, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 34 - Raw AI Output:
# ```json
# {
#   "hotel_name": "8 Adriatico",
#   "distance_miles": "0.43",
#   "guest_rating_out_of_10": "6.0",
#   "number_of_reviews": "2",
#   "price_usd_total": "57",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 35 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Great view of the bay",
#   "distance_miles": "0.43",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "120",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Private kitchen", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 36 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Deluxe Business Suite with Sea View",
#   "distance_miles": "0.43",
#   "guest_rating_out_of_10": "2.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "130",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 37 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Citystate Tower Hotel",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "7.2",
#   "number_of_reviews": "353",
#   "price_usd_total": "62",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 38 - Raw AI Output:
# ```json
# {
#   "hotel_name": "US Embassy Apartments at Bay Sunset",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "93",
#   "room_type_or_description": "Entire apartment, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 39 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sunset Boulevard 360 Ocean View Room",
#   "distance_miles": "0.44",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "189",
#   "room_type_or_description": "Entire condo, Sleeps 4, 2 bedrooms, 2 bathrooms",
#   "amenities": ["Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 40 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Embassy Sea View Room",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "130",
#   "room_type_or_description": "Entire condo, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 41 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sunset Dream Bay",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "2.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "179",
#   "room_type_or_description": "Entire condo, Sleeps 5, 2 bedrooms, 1 bathroom",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 42 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Bayleaf Intramuros Hotel",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "848",
#   "price_usd_total": "82",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 43 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sunset Strip Sea View Room5205",
#   "distance_miles": "0.45",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "214",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 44 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Prince Hotel",
#   "distance_miles": "0.47",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "475",
#   "price_usd_total": "43",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 45 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Roxas Blvd Ermita Studio US Embassy Mla",
#   "distance_miles": "0.48",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "153",
#   "price_usd_total": "29",
#   "room_type_or_description": "Studio",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 46 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel H2O",
#   "distance_miles": "0.49",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1006",
#   "price_usd_total": "86",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 47 - Raw AI Output:
# ```json
# {
#   "hotel_name": "White Knight Hotel Intramuros",
#   "distance_miles": "0.51",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "327",
#   "price_usd_total": "55",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 48 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Go Hotels Ermita",
#   "distance_miles": "0.54",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "164",
#   "price_usd_total": "35",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 49 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Deluxe three-bed room with sea view",
#   "distance_miles": "0.54",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "171",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 50 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Silver Oaks Suite Hotel",
#   "distance_miles": "0.62",
#   "guest_rating_out_of_10": "6.4",
#   "number_of_reviews": "306",
#   "price_usd_total": "35",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later", "In-room dining"]
# }
# ```
#
#
# 🔹 Hotel Block 51 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Dormitels.ph Ermita",
#   "distance_miles": "0.62",
#   "guest_rating_out_of_10": "2.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "27",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 52 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Arzo Hotel Manila",
#   "distance_miles": "0.66",
#   "guest_rating_out_of_10": "5.8",
#   "number_of_reviews": "6",
#   "price_usd_total": "74",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later"]
# }
# ```
#
#
# 🔹 Hotel Block 53 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Palm Hotel Manila",
#   "distance_miles": "0.68",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "450",
#   "price_usd_total": "38",
#   "room_type_or_description": "N/A",
#   "amenities": ["Elevator"]
# }
# ```
#
#
# 🔹 Hotel Block 54 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Suites de Marina Manila",
#   "distance_miles": "0.68",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "11",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 3, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 55 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Eurotel Pedro Gil",
#   "distance_miles": "0.69",
#   "guest_rating_out_of_10": "6.8",
#   "number_of_reviews": "802",
#   "price_usd_total": "50",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 56 - Raw AI Output:
# ```json
# {
#   "hotel_name": "New Coast Hotel Manila",
#   "distance_miles": "0.69",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "1005",
#   "price_usd_total": "115",
#   "room_type_or_description": "N/A",
#   "amenities": ["Outdoor pool", "Restaurant"]
# }
# ```
#
#
# 🔹 Hotel Block 57 - Raw AI Output:
# ```json
# {
#   "hotel_name": "JMM Grand Suites",
#   "distance_miles": "0.7",
#   "guest_rating_out_of_10": "7.2",
#   "number_of_reviews": "535",
#   "price_usd_total": "259",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 58 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Marina Residential Suites",
#   "distance_miles": "0.71",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "36",
#   "price_usd_total": "69",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 59 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Rosh Hotel",
#   "distance_miles": "0.71",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "84",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 60 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Birch Tower Manila",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "6.6",
#   "number_of_reviews": "8",
#   "price_usd_total": "46",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 61 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Birchtower by Jeizel Manila City",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "4.4",
#   "number_of_reviews": "12",
#   "price_usd_total": "36",
#   "room_type_or_description": "N/A",
#   "amenities": ["Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 62 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Kimberly Manila",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "572",
#   "price_usd_total": "62",
#   "room_type_or_description": "Room",
#   "amenities": ["Private kitchen", "VIP Access"]
# }
# ```
#
#
# 🔹 Hotel Block 63 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Arzo Hotel Grand Lodge",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "20",
#   "price_usd_total": "29",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 64 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Bay City View Room with Free Pool",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "9",
#   "price_usd_total": "51",
#   "room_type_or_description": "Manila Bay City View Room with Free Pool",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 65 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Birchtower by Jeizel Manila City By Zuzu",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "35",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 66 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Executive Hotel",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "906",
#   "price_usd_total": "38",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 67 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Regency Grand Suites",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "7.8",
#   "number_of_reviews": "615",
#   "price_usd_total": "87",
#   "room_type_or_description": "Room",
#   "amenities": ["Private kitchenette", "Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 68 - Raw AI Output:
# ```json
# {
#   "hotel_name": "31st floor",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "54",
#   "room_type_or_description": "Entire condo, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 69 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cool suites",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "77",
#   "room_type_or_description": "Entire apartment",
#   "amenities": ["Living area"]
# }
# ```
#
#
# 🔹 Hotel Block 70 - Raw AI Output:
# ```json
# {
#   "hotel_name": "A Condo 2 Bedrooms with 3 minutes walk on Robinsons Mall Manila, Near All perks",
#   "distance_miles": "0.72",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "1",
#   "price_usd_total": "100",
#   "room_type_or_description": "Entire condo, Sleeps 4, 2 bedrooms, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 71 - Raw AI Output:
# ```json
# {
#   "hotel_name": "RentXpressOnline Best Place To Stay",
#   "distance_miles": "0.73",
#   "guest_rating_out_of_10": "3.0",
#   "number_of_reviews": "2",
#   "price_usd_total": "157",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 72 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Deluxe Room W Balcony 60% Discount This Month W Free Sauna & Pool Access",
#   "distance_miles": "0.73",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "258",
#   "room_type_or_description": "Entire apartment, Sleeps 3, 1 bedroom, 0.5 bathrooms",
#   "amenities": ["Sauna", "Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 73 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Pacific Bay Grand Suites",
#   "distance_miles": "0.73",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "68",
#   "price_usd_total": "30",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 74 - Raw AI Output:
# ```json
# {
#   "hotel_name": "One Bedroom Condo with Pool",
#   "distance_miles": "0.73",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "69",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 75 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Las Palmas Hotel de Manila",
#   "distance_miles": "0.73",
#   "guest_rating_out_of_10": "6.6",
#   "number_of_reviews": "191",
#   "price_usd_total": "41",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 76 - Raw AI Output:
# ```json
# {
#   "hotel_name": "One Bedroom Suite in Malate Manila",
#   "distance_miles": "0.73",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "69",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 77 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Tropicana Suites",
#   "distance_miles": "0.74",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "1006",
#   "price_usd_total": "51",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Private kitchen", "VIP Access"]
# }
# ```
#
#
# 🔹 Hotel Block 78 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Rothman Hotel",
#   "distance_miles": "0.74",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "1003",
#   "price_usd_total": "36",
#   "room_type_or_description": "N/A",
#   "amenities": ["Restaurant", "Reception"]
# }
# ```
#
#
# 🔹 Hotel Block 79 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Majestic Hotel (formerly Octagon Mansion Hotel)",
#   "distance_miles": "0.74",
#   "guest_rating_out_of_10": "6.8",
#   "number_of_reviews": "195",
#   "price_usd_total": "31",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 80 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Riviera Mansion Hotel",
#   "distance_miles": "0.75",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "1003",
#   "price_usd_total": "39",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 81 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Manor Hotel",
#   "distance_miles": "0.75",
#   "guest_rating_out_of_10": "4.6",
#   "number_of_reviews": "280",
#   "price_usd_total": "25",
#   "room_type_or_description": "N/A",
#   "amenities": ["Business center"]
# }
# ```
#
#
# 🔹 Hotel Block 82 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Amelie Hotel Manila",
#   "distance_miles": "0.78",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "415",
#   "price_usd_total": "49",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Sundeck", "Meeting facility"]
# }
# ```
#
#
# 🔹 Hotel Block 83 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Diamond Hotel Philippines",
#   "distance_miles": "0.78",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "1004",
#   "price_usd_total": "105",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 84 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sheraton Manila Bay",
#   "distance_miles": "0.81",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "1001",
#   "price_usd_total": "175",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 85 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Pension Natividad",
#   "distance_miles": "0.82",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "154",
#   "price_usd_total": "24",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 86 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Pearl Garden Hotel",
#   "distance_miles": "0.83",
#   "guest_rating_out_of_10": "7.8",
#   "number_of_reviews": "810",
#   "price_usd_total": "62",
#   "room_type_or_description": "N/A",
#   "amenities": ["Breakfast buffet"]
# }
# ```
#
#
# 🔹 Hotel Block 87 - Raw AI Output:
# ```json
# {
#   "hotel_name": "lyf Malate Manila managed by The Ascott Limited",
#   "distance_miles": "0.83",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "30",
#   "price_usd_total": "58",
#   "room_type_or_description": "N/A",
#   "amenities": ["Breakfast area", "Reception"]
# }
# ```
#
#
# 🔹 Hotel Block 88 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Charming 1-bedroom condo in brilliant Manila with AC, fitness room, WiFi",
#   "distance_miles": "0.86",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "88",
#   "room_type_or_description": "Entire condo, 1 bedroom, 2 bathrooms",
#   "amenities": ["Pool", "Kitchen", "Washer and dryer", "AC", "fitness room", "WiFi"]
# }
# ```
#
#
# 🔹 Hotel Block 89 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Abode @The Radiance Manila Bay. Make your stay feel like home",
#   "distance_miles": "0.86",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "106",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 90 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Stay Malate Hostel",
#   "distance_miles": "0.88",
#   "guest_rating_out_of_10": "6.8",
#   "number_of_reviews": "33",
#   "price_usd_total": "19",
#   "room_type_or_description": "N/A",
#   "amenities": ["Dining", "Room", "Balcony", "Check-in/check-out kiosk"]
# }
# ```
#
#
# 🔹 Hotel Block 91 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Victoria Mansions",
#   "distance_miles": "0.9",
#   "guest_rating_out_of_10": "6.2",
#   "number_of_reviews": "54",
#   "price_usd_total": "21",
#   "room_type_or_description": "Room",
#   "amenities": ["Breakfast meal"]
# }
# ```
#
#
# 🔹 Hotel Block 92 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Red Planet Manila Malate Mabini",
#   "distance_miles": "0.91",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "1000",
#   "price_usd_total": "27",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 93 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Homes at Bay Area Suites by SMS Hospitality",
#     "distance_miles": "0.93",
#     "guest_rating_out_of_10": "6.8",
#     "number_of_reviews": "6",
#     "price_usd_total": "45",
#     "room_type_or_description": "N/A",
#     "amenities": ["Pool"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 94 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hop Inn Hotel Ermita Manila",
#   "distance_miles": "0.95",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "1001",
#   "price_usd_total": "38",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 95 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Bayview Luxury Rental",
#   "distance_miles": "0.96",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "22",
#   "price_usd_total": "50",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 96 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Serena's House - Manila",
#   "distance_miles": "0.96",
#   "guest_rating_out_of_10": "7.2",
#   "number_of_reviews": "122",
#   "price_usd_total": "40",
#   "room_type_or_description": "N/A",
#   "amenities": ["Balcony", "Outdoor pool"]
# }
# ```
#
#
# 🔹 Hotel Block 97 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Malate Bayview Mansion",
#   "distance_miles": "0.96",
#   "guest_rating_out_of_10": "6.0",
#   "number_of_reviews": "3",
#   "price_usd_total": "48",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 98 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Manila Lee - Malate Bayview Mansion",
#     "distance_miles": "0.97",
#     "guest_rating_out_of_10": "6.4",
#     "number_of_reviews": "66",
#     "price_usd_total": "49",
#     "room_type_or_description": "N/A",
#     "amenities": ["Pool", "Kitchen"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 99 - Raw AI Output:
# ```json
# {
#   "hotel_name": "OYO 152 Sangco Condotel",
#   "distance_miles": "0.97",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "26",
#   "price_usd_total": "19",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 100 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cozy 1-bedroom fully furnished condo in beautiful Malate Manila",
#   "distance_miles": "0.99",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "20",
#   "price_usd_total": "92",
#   "room_type_or_description": "Entire condo, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 101 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Luxury Studio with WiFi, AC in vibrant Manila",
#   "distance_miles": "0.99",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "50",
#   "room_type_or_description": "Entire apartment, 1 bedroom, 1 bathroom",
#   "amenities": ["WiFi", "AC", "Pool", "Netflix", "Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 102 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Bayview Rental Superior 1BR 1BA w/Balcony Bayview Pool Netflix",
#   "distance_miles": "0.99",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "55",
#   "room_type_or_description": "Entire apartment, 1 bedroom, 1 bathroom",
#   "amenities": ["Bayview", "Pool", "Netflix"]
# }
# ```
#
#
# 🔹 Hotel Block 103 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Orange Nest Hotel",
#   "distance_miles": "1.02",
#   "guest_rating_out_of_10": "6.6",
#   "number_of_reviews": "18",
#   "price_usd_total": "25",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 104 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Citystate Hotel Palanca",
#   "distance_miles": "1.03",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "8",
#   "price_usd_total": "26",
#   "room_type_or_description": "N/A",
#   "amenities": ["Breakfast area"]
# }
# ```
#
#
# 🔹 Hotel Block 105 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Remedios Hotel Manila City Center",
#   "distance_miles": "1.04",
#   "guest_rating_out_of_10": "4.0",
#   "number_of_reviews": "107",
#   "price_usd_total": "34",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 106 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel 99 Quiapo Manila",
#   "distance_miles": "1.06",
#   "guest_rating_out_of_10": "5.2",
#   "number_of_reviews": "34",
#   "price_usd_total": "45",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 107 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Leez Inn Malate",
#   "distance_miles": "1.07",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "787",
#   "price_usd_total": "22",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 108 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Leesons Residences",
#   "distance_miles": "1.07",
#   "guest_rating_out_of_10": "6.6",
#   "number_of_reviews": "426",
#   "price_usd_total": "46",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 109 - Raw AI Output:
# ```json
# {
#   "hotel_name": "OYO 840 Orangenest Apartelle",
#   "distance_miles": "1.08",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "4",
#   "price_usd_total": "21",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later"]
# }
# ```
#
#
# 🔹 Hotel Block 110 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Luxury condo",
#   "distance_miles": "1.08",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "65",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Private kitchen", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 111 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Red Planet Manila Binondo",
#   "distance_miles": "1.08",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "258",
#   "price_usd_total": "30",
#   "room_type_or_description": "N/A",
#   "amenities": ["Business center"]
# }
# ```
#
#
# 🔹 Hotel Block 112 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Go Hotels Otis - Manila",
#   "distance_miles": "1.09",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "164",
#   "price_usd_total": "35",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 113 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Reddoorz Plus @ San Marcelino Malate",
#   "distance_miles": "1.11",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "22",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 114 - Raw AI Output:
# ```json
# {
#   "hotel_name": "8Hostel",
#   "distance_miles": "1.14",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "11",
#   "price_usd_total": "18",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 115 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Citystate Hotel Quiapo",
#   "distance_miles": "1.14",
#   "guest_rating_out_of_10": "7.8",
#   "number_of_reviews": "32",
#   "price_usd_total": "25",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 116 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "The Windy Ridge Hotel Manila",
#     "distance_miles": "1.16",
#     "guest_rating_out_of_10": "7.4",
#     "number_of_reviews": "43",
#     "price_usd_total": "44",
#     "room_type_or_description": "N/A",
#     "amenities": ["Breakfast included", "Fully refundable"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 117 - Raw AI Output:
# ```json
# {
#   "hotel_name": "EDMAR 732 (Family room NO Breakfast Included) Unit #11",
#   "distance_miles": "1.16",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "106",
#   "room_type_or_description": "Family room NO Breakfast Included",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 118 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Lucky Hotel Manila",
#   "distance_miles": "1.18",
#   "guest_rating_out_of_10": "4.8",
#   "number_of_reviews": "164",
#   "price_usd_total": "23",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 119 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Astrotel Avenida",
#   "distance_miles": "1.18",
#   "guest_rating_out_of_10": "5.2",
#   "number_of_reviews": "33",
#   "price_usd_total": "20",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 120 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Ramada by Wyndham Manila Central",
#   "distance_miles": "1.19",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "351",
#   "price_usd_total": "94",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 121 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Lido De Paris Hotel",
#   "distance_miles": "1.2",
#   "guest_rating_out_of_10": "6.2",
#   "number_of_reviews": "30",
#   "price_usd_total": "43",
#   "room_type_or_description": "N/A",
#   "amenities": ["Private kitchenette", "Living room"]
# }
# ```
#
#
# 🔹 Hotel Block 122 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Casa Micarosa Hotel and Residences",
#   "distance_miles": "1.22",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "70",
#   "price_usd_total": "22",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 123 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Armada Hotel",
#   "distance_miles": "1.23",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "1000",
#   "price_usd_total": "59",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 124 - Raw AI Output:
# ```json
# {
#   "hotel_name": "La Casarita",
#   "distance_miles": "1.23",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "19",
#   "price_usd_total": "21",
#   "room_type_or_description": "Room",
#   "amenities": ["Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 125 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Sogo Malate",
#   "distance_miles": "1.24",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "106",
#   "price_usd_total": "27",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 126 - Raw AI Output:
# ```json
# {
#   "hotel_name": "OYO 1011 First Hotel",
#   "distance_miles": "1.26",
#   "guest_rating_out_of_10": "6.4",
#   "number_of_reviews": "43",
#   "price_usd_total": "881",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later"]
# }
# ```
#
#
# 🔹 Hotel Block 127 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Swiss-Belhotel Blulane Manila Philippines",
#   "distance_miles": "1.27",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "45",
#   "price_usd_total": "57",
#   "room_type_or_description": "N/A",
#   "amenities": ["Coffee shop", "Lobby sitting area", "Breakfast area", "Birthday party area"]
# }
# ```
#
#
# 🔹 Hotel Block 128 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Ava Malate, Manila",
#   "distance_miles": "1.27",
#   "guest_rating_out_of_10": "7.8",
#   "number_of_reviews": "157",
#   "price_usd_total": "34",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "In-room dining"]
# }
# ```
#
#
# 🔹 Hotel Block 129 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Halina Hotel Avenida",
#   "distance_miles": "1.28",
#   "guest_rating_out_of_10": "6.0",
#   "number_of_reviews": "29",
#   "price_usd_total": "17",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 130 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Hotel Sogo Quirino Motor Drive Inn",
#     "distance_miles": "1.28",
#     "guest_rating_out_of_10": "5.4",
#     "number_of_reviews": "35",
#     "price_usd_total": "22",
#     "room_type_or_description": "Room",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 131 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Admiral Hotel Manila - MGallery",
#   "distance_miles": "1.29",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "97",
#   "price_usd_total": "142",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 132 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sun Star Grand Hotel",
#   "distance_miles": "1.3",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "125",
#   "price_usd_total": "41",
#   "room_type_or_description": "N/A",
#   "amenities": ["Restaurant"]
# }
# ```
#
#
# 🔹 Hotel Block 133 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Aloha Hotel",
#   "distance_miles": "1.32",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "125",
#   "price_usd_total": "56",
#   "room_type_or_description": "N/A",
#   "amenities": ["Breakfast buffet", "Restaurant"]
# }
# ```
#
#
# 🔹 Hotel Block 134 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Sogo Avenida",
#   "distance_miles": "1.32",
#   "guest_rating_out_of_10": "6.4",
#   "number_of_reviews": "12",
#   "price_usd_total": "29",
#   "room_type_or_description": "N/A",
#   "amenities": ["Elevator"]
# }
# ```
#
#
# 🔹 Hotel Block 135 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Best Fortune Hotel",
#   "distance_miles": "1.32",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "35",
#   "price_usd_total": "25",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 136 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Reddoorz Plus @ Chinatown Binondo",
#   "distance_miles": "1.32",
#   "guest_rating_out_of_10": "5.4",
#   "number_of_reviews": "3",
#   "price_usd_total": "23",
#   "room_type_or_description": "Room",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 137 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Kaizen Suites",
#   "distance_miles": "1.36",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "13",
#   "price_usd_total": "32",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 138 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The SCENIC: Comfortable living by Awsom Phil",
#   "distance_miles": "1.37",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "1",
#   "price_usd_total": "80",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 139 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Green Residences",
#   "distance_miles": "1.39",
#   "guest_rating_out_of_10": "5.0",
#   "number_of_reviews": "4",
#   "price_usd_total": "33",
#   "room_type_or_description": "N/A",
#   "amenities": ["Outdoor pool", "Balcony view", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 140 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Breeze residence Pasay",
#   "distance_miles": "1.39",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "51",
#   "room_type_or_description": "Entire apartment, 1 bedroom, 0.5 bathrooms",
#   "amenities": ["Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 141 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Lucky Chinatown",
#   "distance_miles": "1.42",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "66",
#   "price_usd_total": "45",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 142 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Vista Hotel Recto",
#   "distance_miles": "1.43",
#   "guest_rating_out_of_10": "5.6",
#   "number_of_reviews": "8",
#   "price_usd_total": "25",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 143 - Raw AI Output:
# ```json
# {
#   "hotel_name": "SMDC Jazz Residences Makati",
#   "distance_miles": "1.46",
#   "guest_rating_out_of_10": "1010",
#   "number_of_reviews": "1",
#   "price_usd_total": "66",
#   "room_type_or_description": "Entire apartment, 1 bedroom, 1 bathroom",
#   "amenities": ["Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 144 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Pristinehotel",
#   "distance_miles": "1.49",
#   "guest_rating_out_of_10": "7.2",
#   "number_of_reviews": "13",
#   "price_usd_total": "40",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later"]
# }
# ```
#
#
# 🔹 Hotel Block 145 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Manila Grand Opera Hotel",
#   "distance_miles": "1.52",
#   "guest_rating_out_of_10": "7.2",
#   "number_of_reviews": "265",
#   "price_usd_total": "32",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 146 - Raw AI Output:
# ```json
# {
#   "hotel_name": "A Homey Place Manila, 1 Bedroom",
#   "distance_miles": "1.54",
#   "guest_rating_out_of_10": "9.6",
#   "number_of_reviews": "14",
#   "price_usd_total": "68",
#   "room_type_or_description": "Entire apartment, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 147 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Reddoorz @ The Providence Tower",
#   "distance_miles": "1.62",
#   "guest_rating_out_of_10": "6.6",
#   "number_of_reviews": "4",
#   "price_usd_total": "24",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 148 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Urbanview @ San Antonio's Place Sampaloc Manila",
#   "distance_miles": "1.66",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "19",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 149 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Astrotel Divisoria",
#   "distance_miles": "1.66",
#   "guest_rating_out_of_10": "6.8",
#   "number_of_reviews": "13",
#   "price_usd_total": "26",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 150 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel Benilde Maison De La Salle",
#   "distance_miles": "1.69",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "96",
#   "price_usd_total": "58",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 151 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Capital O 1318 Residences",
#   "distance_miles": "1.7",
#   "guest_rating_out_of_10": "5.4",
#   "number_of_reviews": "3",
#   "price_usd_total": "22",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 152 - Raw AI Output:
# ```json
# {
#   "hotel_name": "OYO 1144 1318 Residences",
#   "distance_miles": "1.7",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "22",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later"]
# }
# ```
#
#
# 🔹 Hotel Block 153 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Mint Homes | CEV Mansion | Ideal for 12 - Perfect for Board Reviews and Exams",
#   "distance_miles": "1.71",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "115",
#   "room_type_or_description": "Entire condo, Sleeps 14, 2 bedrooms, 1 bathroom",
#   "amenities": ["Private kitchen", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 154 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Heroes Hotel",
#   "distance_miles": "1.72",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "80",
#   "price_usd_total": "52",
#   "room_type_or_description": "N/A",
#   "amenities": ["Bar (on property)", "City view"]
# }
# ```
#
#
# 🔹 Hotel Block 155 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Century Park Hotel",
#   "distance_miles": "1.74",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "747",
#   "price_usd_total": "97",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Outdoor spa tub", "Garden"]
# }
# ```
#
#
# 🔹 Hotel Block 156 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Dormitelsph UST",
#   "distance_miles": "1.77",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "4",
#   "price_usd_total": "30",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 157 - Raw AI Output:
# ```json
# {
#   "hotel_name": "UPad Hotel",
#   "distance_miles": "1.79",
#   "guest_rating_out_of_10": "9.0",
# ...
#   "amenities": ["WiFi", "fitness room", "Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 303 - Raw AI Output:
# ```json
# {
#   "hotel_name": "City Stay Inns Slex",
#   "distance_miles": "2.88",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "24",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 304 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Star DeMakati Transient Inn",
#   "distance_miles": "2.88",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "2",
#   "price_usd_total": "31",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later"]
# }
# ```
#
#
# 🔹 Hotel Block 305 - Raw AI Output:
# ```json
# {
#   "hotel_name": "SHORE 1 RESIDENCES",
#   "distance_miles": "2.89",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "56",
#   "room_type_or_description": "N/A",
#   "amenities": ["Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 306 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Sulit Budget Hotel",
#   "distance_miles": "2.89",
#   "guest_rating_out_of_10": "10",
#   "number_of_reviews": "1",
#   "price_usd_total": "25",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Reserve now, pay later", "Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 307 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Seda Residences Makati",
#   "distance_miles": "2.9",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "306",
#   "price_usd_total": "133",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 308 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Exa's Crib Staycation @ MOA Shore 2 Residences",
#   "distance_miles": "2.97",
#   "guest_rating_out_of_10": "9.8",
#   "number_of_reviews": "26",
#   "price_usd_total": "57",
#   "room_type_or_description": "Entire condo, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 309 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "The CUPID: Comfortable living by Awsom Phil",
#     "distance_miles": "2.98",
#     "guest_rating_out_of_10": "1010",
#     "number_of_reviews": "1",
#     "price_usd_total": "78",
#     "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#     "amenities": ["Pool", "Washer and dryer"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 310 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 BR Fully Furnished Condo Across MOA with Pool and Parking - Shore Bldg B, 1246",
#   "distance_miles": "2.98",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "17",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 311 - Raw AI Output:
# ```json
# {
#   "hotel_name": "GemstoneBR in SMDC Shore 2 Residences",
#   "distance_miles": "2.99",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "29",
#   "price_usd_total": "39",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 312 - Raw AI Output:
# ```json
# {
#   "hotel_name": "GemstoneBR in SMDC Shore Residences",
#   "distance_miles": "3.03",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "20",
#   "price_usd_total": "45",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 313 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Robbinsdale Residences",
#   "distance_miles": "3.04",
#   "guest_rating_out_of_10": "6.6",
#   "number_of_reviews": "46",
#   "price_usd_total": "60",
#   "room_type_or_description": "N/A",
#   "amenities": ["Coffee shop"]
# }
# ```
#
#
# 🔹 Hotel Block 314 - Raw AI Output:
# ```json
# {
#   "hotel_name": "One Pacific Place Serviced Residences",
#   "distance_miles": "3.04",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "578",
#   "price_usd_total": "53",
#   "room_type_or_description": "Room",
#   "amenities": ["Exercise/lap pool", "Private kitchenette"]
# }
# ```
#
#
# 🔹 Hotel Block 315 - Raw AI Output:
# ```json
# {
#   "hotel_name": "SPACES HOTEL MAKATI",
#   "distance_miles": "3.04",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "65",
#   "price_usd_total": "50",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 316 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Franchise One Hotel",
#   "distance_miles": "3.04",
#   "guest_rating_out_of_10": "7.2",
#   "number_of_reviews": "79",
#   "price_usd_total": "49",
#   "room_type_or_description": "N/A",
#   "amenities": ["Fully refundable", "Parking"]
# }
# ```
#
#
# 🔹 Hotel Block 317 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 BR Fully Furnished Condo Across MOA with Pool and Parking - Shore Bldg B, 1244",
#   "distance_miles": "3.04",
#   "guest_rating_out_of_10": "9.2",
#   "number_of_reviews": "16",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 318 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Amorsolo Mansion",
#   "distance_miles": "3.05",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "18",
#   "price_usd_total": "48",
#   "room_type_or_description": "N/A",
#   "amenities": ["Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 319 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Herald Suites",
#   "distance_miles": "3.05",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "331",
#   "price_usd_total": "79",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Terrace/patio", "Restaurant"]
# }
# ```
#
#
# 🔹 Hotel Block 320 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Shore 3 1 BR 1006",
#   "distance_miles": "3.06",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "65",
#   "room_type_or_description": "Fully refundable",
#   "amenities": ["Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 321 - Raw AI Output:
# ```json
# {
#   "hotel_name": "SHORE 3 RESIDENCES",
#   "distance_miles": "3.08",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "63",
#   "room_type_or_description": "N/A",
#   "amenities": ["Private kitchen", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 322 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Shore 3 Residences by LUXE",
#     "distance_miles": "3.1",
#     "guest_rating_out_of_10": "1010",
#     "number_of_reviews": "1",
#     "price_usd_total": "68",
#     "room_type_or_description": "N/A",
#     "amenities": ["Pool", "Fully refundable", "Reserve now, pay later"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 323 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Mini Suites - Eton Tower Makati",
#   "distance_miles": "3.11",
#   "guest_rating_out_of_10": "7.6",
#   "number_of_reviews": "1005",
#   "price_usd_total": "36",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 324 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Lanson Place Mall of Asia Manila",
#   "distance_miles": "3.11",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "108",
#   "price_usd_total": "173",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 325 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Comfy One Bedroom with Stunning View in Makati CBD",
#   "distance_miles": "3.11",
#   "guest_rating_out_of_10": "5.0",
#   "number_of_reviews": "2",
#   "price_usd_total": "77",
#   "room_type_or_description": "Entire condo, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 326 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Midas Hotel & Casino",
#   "distance_miles": "3.13",
#   "guest_rating_out_of_10": "7.8",
#   "number_of_reviews": "716",
#   "price_usd_total": "78",
#   "room_type_or_description": "N/A",
#   "amenities": ["Breakfast buffet"]
# }
# ```
#
#
# 🔹 Hotel Block 327 - Raw AI Output:
# ```json
# {
#   "hotel_name": "A clean and comfortable little nest",
#   "distance_miles": "3.14",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "154",
#   "room_type_or_description": "Entire home, Sleeps 2, 1 bedroom, 1 bathroom",
#   "amenities": ["Fully refundable"]
# }
# ```
#
#
# 🔹 Hotel Block 328 - Raw AI Output:
# ```json
# {
#   "hotel_name": "NEW!! Affordable Gateaway @ HEART of MNL",
#   "distance_miles": "3.14",
#   "guest_rating_out_of_10": "7.4",
#   "number_of_reviews": "3",
#   "price_usd_total": "60",
#   "room_type_or_description": "Entire apartment, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 329 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Christine Suites at The Beacon Makati",
#   "distance_miles": "3.15",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "137",
#   "price_usd_total": "40",
#   "room_type_or_description": "Entire condo",
#   "amenities": ["Outdoor pool", "Private kitchenette", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 330 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 BR Fully Furnished Condo across MOA with Pool and Parking - Shore 3, Unit 1145",
#   "distance_miles": "3.2",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "11",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 331 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 BR Fully Furnished Condo across MOA with Pool and Parking - Shore3 Unit 1144",
#   "distance_miles": "3.2",
#   "guest_rating_out_of_10": "8.8",
#   "number_of_reviews": "13",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 332 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Selah Garden Hotel Manila",
#   "distance_miles": "3.22",
#   "guest_rating_out_of_10": "7.0",
#   "number_of_reviews": "12",
#   "price_usd_total": "43",
#   "room_type_or_description": "N/A",
#   "amenities": []
# }
# ```
#
#
# 🔹 Hotel Block 333 - Raw AI Output:
# ```json
# {
#   "hotel_name": "KL Executive Greenbelt KLX",
#   "distance_miles": "3.22",
#   "guest_rating_out_of_10": "9.6",
#   "number_of_reviews": "156",
#   "price_usd_total": "86",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 334 - Raw AI Output:
# ```json
# {
#   "hotel_name": "KL Tower 117 Gamboa Street",
#   "distance_miles": "3.22",
#   "guest_rating_out_of_10": "8.0",
#   "number_of_reviews": "4",
#   "price_usd_total": "77",
#   "room_type_or_description": "Entire apartment, Sleeps 3, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 335 - Raw AI Output:
# ```json
# {
#   "hotel_name": "KL Tower",
#   "distance_miles": "3.23",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "12",
#   "price_usd_total": "66",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 336 - Raw AI Output:
# ```json
# {
#   "hotel_name": "KL Serviced Residences",
#   "distance_miles": "3.23",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "565",
#   "price_usd_total": "57",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Private kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 337 - Raw AI Output:
# ```json
# {
#   "hotel_name": "NEW! Cozy Shell Residences w/Balcony—Pool View",
#   "distance_miles": "3.23",
#   "guest_rating_out_of_10": "9.8",
#   "number_of_reviews": "138",
#   "price_usd_total": "123",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bathroom",
#   "amenities": ["Pool", "Kitchen", "Washer and dryer"]
# }
# ```
#
#
# 🔹 Hotel Block 338 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Somerset Central Salcedo Makati",
#   "distance_miles": "3.24",
#   "guest_rating_out_of_10": "9.4",
#   "number_of_reviews": "145",
#   "price_usd_total": "121",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool", "Dining", "Reception"]
# }
# ```
#
#
# 🔹 Hotel Block 339 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 BR Fully Furnished Condo Across MOA with Pool and Parking - S Res. Unit 0916",
#   "distance_miles": "3.25",
#   "guest_rating_out_of_10": "1010",
#   "number_of_reviews": "2",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 340 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Shell Residences Condominium is in front of SM Mall of Asia and 10min to Airport",
#   "distance_miles": "3.25",
#   "guest_rating_out_of_10": "2.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "68",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 341 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Chic Shell Residences Condo Suite -- MOA view",
#     "distance_miles": "3.25",
#     "guest_rating_out_of_10": "6.0",
#     "number_of_reviews": "2",
#     "price_usd_total": "123",
#     "room_type_or_description": "Entire apartment, Sleeps 4, 1 bathroom",
#     "amenities": ["Pool", "Kitchen"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 342 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Joyce Apartelle Kalentong",
#   "distance_miles": "3.27",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "22",
#   "price_usd_total": "32",
#   "room_type_or_description": "N/A",
#   "amenities": ["Private kitchenette"]
# }
# ```
#
#
# 🔹 Hotel Block 343 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Cozy Nook. Across Greenbelt5. WiFi.Pool.Netflix",
#     "distance_miles": "3.28",
#     "guest_rating_out_of_10": "6.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "81",
#     "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#     "amenities": ["Pool", "Kitchen", "WiFi", "Netflix"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 344 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 BR Fully Furnished Condo across MOA with Pool and Parking - Shore 3 Unit 1146",
#   "distance_miles": "3.29",
#   "guest_rating_out_of_10": "8.6",
#   "number_of_reviews": "20",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 345 - Raw AI Output:
# ```json
# {
#   "hotel_name": "1 BR Fully Furnished Condo in Makati with Pool and Parking - Red Residences 1131",
#   "distance_miles": "3.29",
#   "guest_rating_out_of_10": "9.6",
#   "number_of_reviews": "4",
#   "price_usd_total": "64",
#   "room_type_or_description": "Entire condo, Sleeps 4, 1 bedroom, 1 bathroom",
#   "amenities": ["Pool", "Kitchen"]
# }
# ```
#
#
# 🔹 Hotel Block 346 - Raw AI Output:
# ```json
# {
#   "hotel_name": "The Sphere Serviced Residences Managed by HII",
#   "distance_miles": "3.31",
#   "guest_rating_out_of_10": "9.0",
#   "number_of_reviews": "376",
#   "price_usd_total": "63",
#   "room_type_or_description": "N/A",
#   "amenities": ["Pool"]
# }
# ```
#
#
# 🔹 Hotel Block 347 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Hotel 101 - Manila",
#   "distance_miles": "3.31",
#   "guest_rating_out_of_10": "8.4",
#   "number_of_reviews": "2160",
#   "price_usd_total": "61",
#   "room_type_or_description": "N/A",
#   "amenities": ["Outdoor pool", "Private kitchenette"]
# }
# ```
#
#
# ✅ Final structured hotel DataFrame preview:
#
#                                           hotel_name distance_miles  \
# 0  Maria Clara - Kalaw Ave · Filipino Themed Luxu...           0.15
# 1                      Ocean view studio room (1bed)           0.27
# 2    Manila Chic London Street, coffee bar Oceanview           0.27
# 3                          City Garden Suites Manila           0.29
# 4                                  Anex Hotel-Manila            0.3
#
#   guest_rating_out_of_10 number_of_reviews price_usd_total  \
# 0                    9.8                60             185
# 1                    2.0                 1              87
# 2                    8.0                 1             130
# 3                    8.4              1001              55
# 4                    7.0               616              38
#
#                             room_type_or_description          amenities
# 0     Entire condo, Sleeps 6, 2 bedrooms, 1 bathroom    [Pool, Kitchen]
# 1  Entire apartment, Sleeps 2, 1 bedroom, 1 bathroom    [Pool, Kitchen]
# 2      Entire condo, Sleeps 4, 1 bedroom, 1 bathroom  [Private kitchen]
# 3                                                N/A                 []
# 4                                                N/A                 []

# %%
df_structured = df_structured.dropna(subset=['price_usd_total'])
df_structured
# Out:
#                                             hotel_name distance_miles  \
# 0    Maria Clara - Kalaw Ave · Filipino Themed Luxu...           0.15
# 1                        Ocean view studio room (1bed)           0.27
# 2      Manila Chic London Street, coffee bar Oceanview           0.27
# 3                            City Garden Suites Manila           0.29
# 4                                    Anex Hotel-Manila            0.3
# ..                                                 ...            ...
# 345    Cozy Nook. Across Greenbelt5. WiFi.Pool.Netflix           3.28
# 346  1 BR Fully Furnished Condo across MOA with Poo...           3.29
# 347  1 BR Fully Furnished Condo in Makati with Pool...           3.29
# 348      The Sphere Serviced Residences Managed by HII           3.31
# 349                                 Hotel 101 - Manila           3.31
#
#     guest_rating_out_of_10 number_of_reviews price_usd_total  \
# 0                      9.8                60             185
# 1                      2.0                 1              87
# 2                      8.0                 1             130
# 3                      8.4              1001              55
# 4                      7.0               616              38
# ..                     ...               ...             ...
# 345                    6.0                 1              81
# 346                    8.6                20              64
# 347                    9.6                 4              64
# 348                    9.0               376              63
# 349                    8.4              2160              61
#
#                               room_type_or_description  \
# 0       Entire condo, Sleeps 6, 2 bedrooms, 1 bathroom
# 1    Entire apartment, Sleeps 2, 1 bedroom, 1 bathroom
# 2        Entire condo, Sleeps 4, 1 bedroom, 1 bathroom
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 345      Entire condo, Sleeps 4, 1 bedroom, 1 bathroom
# 346      Entire condo, Sleeps 4, 1 bedroom, 1 bathroom
# 347      Entire condo, Sleeps 4, 1 bedroom, 1 bathroom
# 348                                                N/A
# 349                                                N/A
#
#                                amenities
# 0                        [Pool, Kitchen]
# 1                        [Pool, Kitchen]
# 2                      [Private kitchen]
# 3                                     []
# 4                                     []
# ..                                   ...
# 345       [Pool, Kitchen, WiFi, Netflix]
# 346                      [Pool, Kitchen]
# 347                      [Pool, Kitchen]
# 348                               [Pool]
# 349  [Outdoor pool, Private kitchenette]
#
# [350 rows x 7 columns]

# %%
df_structured.to_excel('Philippines_expedia_ai.xlsx',index = False)
