# %%
from pathlib import Path
import pandas as pd
import re
from openai import OpenAI
import ast

# %%
# Load the Booking.com Osaka Castle text file
file_path = Path("Booking.com_ Search results_ Rizal Park, Manila, Luzon, Philippines. Book your hotel now!.txt")
with open(file_path, "r", encoding="utf-8") as file:
    booking_text = file.read()

# Improved chunking: Split before "Show on map <https://www.booking.com/hotel/"
pattern = r"(?=Show on map <https://www\.booking\.com/hotel/)"
hotel_blocks = re.split(pattern, booking_text)

# Remove small/trivial entries
hotel_blocks = [block.strip() for block in hotel_blocks if len(block.strip()) > 300]

# Store in DataFrame
df_blocks = pd.DataFrame({"Hotel Block": hotel_blocks})
df_blocks = df_blocks.iloc[1:].reset_index(drop=True)
df_blocks
# Out:
#                                            Hotel Block
# 0    Show on map <https://www.booking.com/hotel/ph/...
# 1    Show on map <https://www.booking.com/hotel/ph/...
# 2    Show on map <https://www.booking.com/hotel/ph/...
# 3    Show on map <https://www.booking.com/hotel/ph/...
# 4    Show on map <https://www.booking.com/hotel/ph/...
# ..                                                 ...
# 995  Show on map <https://www.booking.com/hotel/ph/...
# 996  Show on map <https://www.booking.com/hotel/ph/...
# 997  Show on map <https://www.booking.com/hotel/ph/...
# 998  Show on map <https://www.booking.com/hotel/ph/...
# 999  Show on map <https://www.booking.com/hotel/ph/...
#
# [1000 rows x 1 columns]

# %%
api_key = 'sk-9c8a52fa5ba140608bb8484c3a27cffa'

# %%
# Initialize DeepSeek API
client = OpenAI(
    api_key= api_key,  # Replace with your key
    base_url="https://api.deepseek.com"
)

# General prompt for Booking.com-style hotel chunks
system_prompt = (
    "You are processing a printed text block from a Booking.com search result. "
    "Each block contains the description of one hotel. Extract only the visible data. "
    "Return the result as valid JSON (object or list of objects).\n\n"
    "Each hotel must contain:\n"
    "{\n"
    "  \"hotel_name\": \"\",\n"
    "  \"distance_miles\": \"\",            # Numeric only. No 'mi', no location names\n"
    "  \"guest_rating_out_of_10\": \"\",    # e.g. '8.6'\n"
    "  \"number_of_reviews\": \"\",         # e.g. '112'\n"
    "  \"price_usd_total\": \"\",           # e.g. '75'. No '$', no 'USD', no 'total'\n"
    "  \"room_type_or_description\": \"\",\n"
    "  \"amenities\": [\"\", \"\"]\n"
    "}\n\n"
    "Strict rules:\n"
    "- All numeric fields must be clean numbers as strings.\n"
    "- Do NOT include units or extra words.\n"
    "- Use \"N/A\" if the value is missing."
)

# %%
# Load hotel blocks
hotel_blocks = df_blocks["Hotel Block"].tolist()

results = []

for i, block in enumerate(hotel_blocks):
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": block}
        ],
        temperature=0.0,
        stream=False
    )

    raw = response.choices[0].message.content.strip()
    print(f"\n🔹 Hotel Block {i} - Raw AI Output:\n{raw}\n")

    cleaned = raw.strip("` \n")
    if cleaned.startswith("json"):
        cleaned = cleaned[4:].strip()

    try:
        parsed = ast.literal_eval(cleaned)
        if isinstance(parsed, dict):
            results.append(parsed)
        elif isinstance(parsed, list):
            results.extend(parsed)
        else:
            raise ValueError("Parsed output is not a dict or list")
    except Exception as e:
        print(f"❌ Parse error on block {i}: {e}")
        results.append({
            "hotel_name": "ERROR",
            "distance_miles": "ERROR",
            "guest_rating_out_of_10": "ERROR",
            "number_of_reviews": "ERROR",
            "price_usd_total": "ERROR",
            "room_type_or_description": "ERROR",
            "amenities": ["ERROR"]
        })

# Save to DataFrame
df_booking_structured = pd.DataFrame(results)
print("\n✅ Final structured DataFrame preview:")
print(df_booking_structured.head())
# Out:
# 🔹 Hotel Block 0 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Comfy Inn Manila Kalaw by Reddoorz",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "39",
#     "room_type_or_description": "Twin Room",
#     "amenities": ["2 twin beds"]
#   },
#   {
#     "hotel_name": "Eton Baypark Manila Studio Unit By Tripleview Condominium",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 1 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Eton Baypark Manila by Tripleview 2 Lovely Unit",
#   "distance_miles": "0",
#   "guest_rating_out_of_10": "6.8",
#   "number_of_reviews": "7",
#   "price_usd_total": "39",
#   "room_type_or_description": "Studio Apartment with Queen Bed",
#   "amenities": [
#     "Entire apartment",
#     "1 bedroom",
#     "1 living room",
#     "1 bathroom",
#     "1 kitchen",
#     "430.6ft²",
#     "2 beds (1 full, 1 sofa bed)"
#   ]
# }
# ```
#
#
# 🔹 Hotel Block 2 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Eton Baypark",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.9",
#     "number_of_reviews": "290",
#     "price_usd_total": "40",
#     "room_type_or_description": "Studio Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 bathroom",
#       "1 kitchen",
#       "301.4ft²",
#       "1 full bed"
#     ]
#   },
#   {
#     "hotel_name": "Stunning Sunset Retreat at Eton Bayview II 2pax",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 3 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Stunning Sunset Retreat at Eton Bayview II 2pax",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "79",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "2 beds (1 queen, 1 futon)"
#     ]
#   },
#   {
#     "hotel_name": "Luxury Condo in Manila Bay near US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "495",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 4 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Luxury Condo in Manila Bay near US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "10",
#     "number_of_reviews": "1",
#     "price_usd_total": "87",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["2 queen beds"]
#   },
#   {
#     "hotel_name": "Miramar Hotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 5 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Miramar",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.4",
#     "number_of_reviews": "47",
#     "price_usd_total": "26",
#     "room_type_or_description": "Superior Double Room",
#     "amenities": ["1 full bed"]
#   },
#   {
#     "hotel_name": "Dormitels.ph Ermita",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 6 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Dormitels - PH UN",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "4.6",
#     "number_of_reviews": "73",
#     "price_usd_total": "17",
#     "room_type_or_description": "Double Room, 1 full bed",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "Slouch Hat Hotel and Restaurant",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 7 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Slouch Hat and Restaurant",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "5.2",
#     "number_of_reviews": "5",
#     "price_usd_total": "32",
#     "room_type_or_description": "Deluxe Double Room",
#     "amenities": ["1 full bed"]
#   },
#   {
#     "hotel_name": "Suites de Marina Manila with Netflix",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "385",
#     "room_type_or_description": "N/A",
#     "amenities": ["N/A"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 8 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Suites de Marina Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.8",
#     "number_of_reviews": "8",
#     "price_usd_total": "68",
#     "room_type_or_description": "Entire apartment • 1 bedroom • 1 living room • 1 bathroom • 1 kitchen • 699.7ft² 1 queen bed",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Anex Hotel near US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 9 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Anex Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.0",
#     "number_of_reviews": "602",
#     "price_usd_total": "28",
#     "room_type_or_description": "Standard Double Room",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "The Manila Hotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 10 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "The Manila Hotel",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.5",
#     "number_of_reviews": "1900",
#     "price_usd_total": "109",
#     "room_type_or_description": "Grand Deluxe, 1 king bed",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Paragon Tower Hotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 11 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Paragon Tower",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "441",
#     "price_usd_total": "25",
#     "room_type_or_description": "Standard Double Room",
#     "amenities": ["1 queen bed"]
#   },
#   {
#     "hotel_name": "Airo Hotel Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 12 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Airo",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.4",
#     "number_of_reviews": "763",
#     "price_usd_total": "27",
#     "room_type_or_description": "Economy Double Room without Window",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "Rizal Park Hotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 13 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Rizal Park Hotel",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.5",
#     "number_of_reviews": "490",
#     "price_usd_total": "64",
#     "room_type_or_description": "Deluxe King Room",
#     "amenities": ["Breakfast included"]
#   },
#   {
#     "hotel_name": "City Garden Suites Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 14 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "City Garden Suites",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "1454",
#     "price_usd_total": "52",
#     "room_type_or_description": "Standard Twin Room No View",
#     "amenities": [
#       "2 twin beds",
#       "Breakfast included",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Hotel Juliano",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 15 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Juliano",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.1",
#     "number_of_reviews": "93",
#     "price_usd_total": "20",
#     "room_type_or_description": "Economy Double Room",
#     "amenities": ["1 full bed"]
#   },
#   {
#     "hotel_name": "Hotel H2O",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 16 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "H2O",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.3",
#     "number_of_reviews": "368",
#     "price_usd_total": "70",
#     "room_type_or_description": "Twin Room with Park View",
#     "amenities": [
#       "2 twin beds",
#       "Breakfast included"
#     ]
#   },
#   {
#     "hotel_name": "Bayview Park Hotel Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 17 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Bayview Park Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.8",
#     "number_of_reviews": "1496",
#     "price_usd_total": "47",
#     "room_type_or_description": "Superior Twin or Double",
#     "amenities": [
#       "1 full bed",
#       "Breakfast included",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Torre de Manila 1BR",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "Torre de Manila 1BR",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 18 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Torre de Manila Taft 1702",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.0",
#     "number_of_reviews": "3",
#     "price_usd_total": "50",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["2 beds (1 full, 1 bunk bed)"]
#   },
#   {
#     "hotel_name": "Red Planet Manila Bay",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 19 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Red Planet Manila Bay",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.2",
#     "number_of_reviews": "2558",
#     "price_usd_total": "36",
#     "room_type_or_description": "Double Room, 1 queen bed",
#     "amenities": []
#   },
#   {
#     "hotel_name": "DUCK INN AND RESTAURANT",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 20 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Duck Inn and Restaurant",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.3",
#     "number_of_reviews": "49",
#     "price_usd_total": "29",
#     "room_type_or_description": "Deluxe Room",
#     "amenities": ["Breakfast included"]
#   },
#   {
#     "hotel_name": "CityState Tower Hotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 21 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Citystate",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.4",
#     "number_of_reviews": "25",
#     "price_usd_total": "34",
#     "room_type_or_description": "Standard Double Room",
#     "amenities": [
#       "1 full bed",
#       "Breakfast included",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Rosas Garden Hotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 22 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Rosas Garden",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.9",
#     "number_of_reviews": "155",
#     "price_usd_total": "28",
#     "room_type_or_description": "Standard Double Room",
#     "amenities": ["1 queen bed", "Free cancellation"]
#   },
#   {
#     "hotel_name": "Stunning & Luxury 4BR in Manila Bay White Beach",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 23 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "stunning & luxury 4br in manila bay white beach",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "311",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["Free airport taxi"]
#   },
#   {
#     "hotel_name": "MANILA BAY FRONT DELUX Pearl of the orient",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "350",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 24 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Pearl of the Orient Manila",
#   "distance_miles": "0",
#   "guest_rating_out_of_10": "6.7",
#   "number_of_reviews": "81",
#   "price_usd_total": "62",
#   "room_type_or_description": "Studio with Balcony",
#   "amenities": ["Entire studio", "1 bathroom", "1 kitchen", "Free cancellation"]
# }
# ```
#
#
# 🔹 Hotel Block 25 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Pearl of the Orient",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.7",
#     "number_of_reviews": "46",
#     "price_usd_total": "62",
#     "room_type_or_description": "Studio with Balcony",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "441.3ft²",
#       "2 queen beds",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Urban Sleek stay fronting the US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "315",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 26 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Urban Sleek Stay Fronting the US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "55",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["2 beds (1 sofa bed, 1 queen)"]
#   },
#   {
#     "hotel_name": "duck inn manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "162",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 27 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Duck Inn Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "38",
#     "price_usd_total": "29",
#     "room_type_or_description": "Deluxe Queen Room",
#     "amenities": ["Breakfast included"]
#   },
#   {
#     "hotel_name": "Manila Lotus Hotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 28 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Lotus Garden",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.4",
#     "number_of_reviews": "1261",
#     "price_usd_total": "33",
#     "room_type_or_description": "Standard Double Room (No View)",
#     "amenities": ["1 full bed", "Breakfast included", "Free cancellation"]
#   },
#   {
#     "hotel_name": "Torre de manila taft 23",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 29 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Torre de Manila Taft 23",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "40",
#     "room_type_or_description": "Double Room (3 beds: 2 fulls, 1 queen)",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Bless View at 16th",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 30 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Bless View at 16th",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "40",
#     "room_type_or_description": "Family Room, 1 full bed",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Torre De Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "315",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 31 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Torre de Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "55",
#     "room_type_or_description": "Entire apartment • 1 bedroom • 1 living room • 1 bathroom • 1 kitchen • 366ft²",
#     "amenities": ["3 beds (1 full, 2 sofa beds)"]
#   },
#   {
#     "hotel_name": "Comfort Stay at Intramuros by IN CAFEBAR",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "266",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 32 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Comfort Stay at Intramuros by in Cafebar",
#   "distance_miles": "0.3",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "47",
#   "room_type_or_description": "Two-Bedroom Apartment",
#   "amenities": ["Entire apartment", "1 bedroom", "1 bathroom", "1 full bed"]
# }
# ```
#
#
# 🔹 Hotel Block 33 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Jack n Jellos Maynila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.5",
#     "number_of_reviews": "71",
#     "price_usd_total": "63",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 bathroom",
#       "1 kitchen",
#       "398.3ft²",
#       "2 queen beds",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "2 Bedroom in Grand Riviera Suites infront of US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "2 Bedroom in Grand Riviera Suites infront of US Embassy",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 34 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Apartment with Sea View",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "143",
#     "room_type_or_description": "Entire apartment • 1 bedroom • 1 living room • 2 bathrooms • 1 kitchen • 3 beds (1 full, 1 king, 1 sofa bed)",
#     "amenities": []
#   },
#   {
#     "hotel_name": "US Embassy Roxas Blvd, Ermita, Manila 1 Bedroom ComfySuite",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 35 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "US Embassy 1bedroom Comfy Suite 47 Roxas Blvd Ermita Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.4",
#     "number_of_reviews": "20",
#     "price_usd_total": "57",
#     "room_type_or_description": "One-Bedroom Suite",
#     "amenities": [
#       "Private suite",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "462.9ft²",
#       "2 beds (1 sofa bed, 1 queen)"
#     ]
#   },
#   {
#     "hotel_name": "MANILA BAY EXECUTIVE SUITE pearl of orient",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 36 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Manila Bay Suite Pearl of Orient",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.6",
#     "number_of_reviews": "5",
#     "price_usd_total": "271",
#     "room_type_or_description": "Entire apartment • 3 bedrooms • 1 living room • 2 bathrooms • 1 kitchen • 1,636.1ft²",
#     "amenities": ["7 beds (3 sofa beds, 4 queens)"]
#   },
#   {
#     "hotel_name": "8 Adriatico Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 37 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Short Stay Accommodation in Ermita Manila near PGH US Embassy and St Lukes Medic",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.1",
#     "number_of_reviews": "43",
#     "price_usd_total": "56",
#     "room_type_or_description": "Studio with Sea View",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "269.1ft²",
#       "2 beds (1 twin, 1 sofa bed)"
#     ]
#   },
#   {
#     "hotel_name": "Modern and Cozy Condo in 8Adriatico near PGH, SLMEC and US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 38 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Condo for short stay available in 8Adriatico near St. Lukes and US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.7",
#     "number_of_reviews": "4",
#     "price_usd_total": "79",
#     "room_type_or_description": "Studio with Ocean View",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "269.1ft²",
#       "1 full bed"
#     ]
#   },
#   {
#     "hotel_name": "1 Bedroom Homestay in 8 Adriatico Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 39 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Modern Studio Units with City View",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.5",
#     "number_of_reviews": "2",
#     "price_usd_total": "58",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["Entire apartment", "1 bedroom", "1 bathroom", "1 full bed"]
#   },
#   {
#     "hotel_name": "8 Adriatico 1 Bedroom Condo Unit",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 40 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "One-Bedroom Apartment",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.2",
#     "number_of_reviews": "7",
#     "price_usd_total": "79",
#     "room_type_or_description": "Entire apartment • 1 bedroom • 1 living room • 1 bathroom • 538.2ft² • 4 beds (2 sofa beds, 2 queens)",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Furnished Studio in 8 Adriatico",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 41 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Moder Studio Units by Airspace Manila in 8 Adriatico",
#   "distance_miles": "0",
#   "guest_rating_out_of_10": "8.7",
#   "number_of_reviews": "3",
#   "price_usd_total": "52",
#   "room_type_or_description": "One-Bedroom Apartment",
#   "amenities": ["Entire apartment", "1 bedroom", "1 bathroom", "1 full bed"]
# }
# ```
#
#
# 🔹 Hotel Block 42 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "One Bedroom Condo with Balcony in Manila near US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "91",
#     "room_type_or_description": "Apartment, 1 full bed",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Modern Condo near US Embassy and St Lukes Ermita",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 43 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Modern Condo near US Embassy and St Lukes Ermita",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "142",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["Entire apartment", "1 bedroom", "1 bathroom", "1 full bed"]
#   },
#   {
#     "hotel_name": "Grand Riviera Suites",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 44 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Grand Riviera Suites Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.5",
#     "number_of_reviews": "6",
#     "price_usd_total": "35",
#     "room_type_or_description": "Deluxe Queen Studio",
#     "amenities": ["Entire studio", "1 bathroom", "204.5ft²", "2 beds (1 twin, 1 full)"]
#   },
#   {
#     "hotel_name": "Cozy Studio in Front of US Embassy, Ermita, Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 45 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Cozy studio in front of us embassy ermita manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.0",
#     "number_of_reviews": "2",
#     "price_usd_total": "51",
#     "room_type_or_description": "Studio",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "269.1ft²",
#       "3 beds (1 twin, 2 futons)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Grand Riviera suite Condotel",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 46 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Grand Riviera Suite Condotel",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.0",
#     "number_of_reviews": "6",
#     "price_usd_total": "33",
#     "room_type_or_description": "King Studio",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "1 king bed"
#     ]
#   },
#   {
#     "hotel_name": "White Knight Hotel Intramuros",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 47 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "White Knight Intramuros",
#     "distance_miles": "0.3",
#     "guest_rating_out_of_10": "5.9",
#     "number_of_reviews": "233",
#     "price_usd_total": "29",
#     "room_type_or_description": "Deluxe Queen Room",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "Simple & Cozy 1 Bedroom US Embassy, Roxas Blvd, Ermita, Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 48 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Simple & Cozy 1 Bedroom US Embassy Roxas Blvd Ermita Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.0",
#     "number_of_reviews": "3",
#     "price_usd_total": "56",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["1 full bed", "Free cancellation"]
#   },
#   {
#     "hotel_name": "Grand Riviera Suites Condotel by Jen",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 49 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Grand Riviera Suites Condotel by Jen",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.8",
#     "number_of_reviews": "4",
#     "price_usd_total": "31",
#     "room_type_or_description": "Studio",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "Cozy Room in Front of US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 50 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Cozy room in front of US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.5",
#     "number_of_reviews": "4",
#     "price_usd_total": "37",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "1 Bedroom US Embassy Roxas Blvd. Ermita Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 51 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "One-Bedroom Apartment",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "1.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "55",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["1 full bed", "Free cancellation"]
#   },
#   {
#     "hotel_name": "SnugglePod Condotel - Grand Riviera Suites, US Embassy Manila, Roxas Blvd",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 52 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Junior Studio Roxas Blvd Ermita Manila US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.0",
#     "number_of_reviews": "30",
#     "price_usd_total": "29",
#     "room_type_or_description": "Standard Studio",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "226ft²",
#       "1 queen bed"
#     ]
#   },
#   {
#     "hotel_name": "Beachfront U.S. Embassy Family Retreat",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 53 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Beachfront US Embassy Family Retreat",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.3",
#     "number_of_reviews": "231",
#     "price_usd_total": "59",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "1 kitchen",
#       "301.4ft²",
#       "1 full bed",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Grand Riviera Suites",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 54 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Grand Riviera Suites Apartment",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.4",
#     "number_of_reviews": "45",
#     "price_usd_total": "53",
#     "room_type_or_description": "Studio",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "1 full bed"
#     ]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 55 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Grand Riviera Suites",
#   "distance_miles": "0",
#   "guest_rating_out_of_10": "8.2",
#   "number_of_reviews": "9",
#   "price_usd_total": "54",
#   "room_type_or_description": "Entire apartment • 1 bedroom • 1 bathroom • 236.8ft² 1 full bed",
#   "amenities": ["N/A"]
# }
# ```
#
#
# 🔹 Hotel Block 56 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Beachside Embassy Apartment",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.8",
#     "number_of_reviews": "135",
#     "price_usd_total": "62",
#     "room_type_or_description": "Queen Studio",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "Sunset House Roxas Bay",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 57 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Sunset House Roxas Bay",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.1",
#     "number_of_reviews": "14",
#     "price_usd_total": "49",
#     "room_type_or_description": "Deluxe Double Room with Side Sea View",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "Embassy Waves Retreat",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 58 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Embassy Waves Retreat",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "47",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["1 full bed"]
#   },
#   {
#     "hotel_name": "Manila Bayscape",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 59 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Manila Bayscape",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "5.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "68",
#     "room_type_or_description": "Two-Bedroom Apartment",
#     "amenities": ["2 queen beds"]
#   },
#   {
#     "hotel_name": "1 Bedroom Condotel infront of US Embassy with Partial Bay View",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "1 Bedroom Condotel infront of US Embassy with Partial Bay View",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 60 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Grand Riviera Suites Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "63",
#     "room_type_or_description": "Deluxe Suite with Sea View",
#     "amenities": [
#       "Private suite",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "430.6ft²",
#       "4 beds (2 sofa beds, 2 queens)"
#     ]
#   },
#   {
#     "hotel_name": "US Embassy, Cozy Condo, Ermita, Manila Roxas Blvd",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 61 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "US Embassy Cozy Condo Ermita Manila Roxas Blvd",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "5.5",
#     "number_of_reviews": "2",
#     "price_usd_total": "41",
#     "room_type_or_description": "Studio Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 bathroom",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Grand Riviera Condo",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 62 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Grand Riviera Condo",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "1.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "57",
#     "room_type_or_description": "Deluxe One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 bathroom",
#       "1 kitchen",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "日落海湾公馆",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 63 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Ri Luo Hai Wan Gong Guan",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "1.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "86",
#     "room_type_or_description": "One-Bedroom Family Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "1 kitchen",
#       "516.7ft²",
#       "3 beds (2 sofa beds, 1 queen)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Partial Ocean View Opposite the US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 64 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Partial Ocean View Opposite the US Embassy Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "1.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "114",
#     "room_type_or_description": "Two-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "2 bedrooms",
#       "1 bathroom",
#       "592ft²",
#       "2 full beds"
#     ]
#   },
#   {
#     "hotel_name": "Comfy Condo Grand Riviera Suite, Roxas Blvd Ermita Manila infront of US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 65 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Roxas Blvd Stunning Studio Condo Near US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.0",
#     "number_of_reviews": "3",
#     "price_usd_total": "50",
#     "room_type_or_description": "Standard Studio",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "215.3ft²",
#       "2 beds (1 twin, 1 futon)"
#     ]
#   },
#   {
#     "hotel_name": "Roxas Blvd Stunning Studio Condo Near US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "170",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 66 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Roxas Blvd Stunning Studio Condo near US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.7",
#     "number_of_reviews": "298",
#     "price_usd_total": "30",
#     "room_type_or_description": "Studio Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 bathroom",
#       "1 kitchen",
#       "236.8ft²",
#       "2 beds (1 full, 1 futon)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "New Condo at Grand Riviera Suites across US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 67 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Gintalana Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.5",
#     "number_of_reviews": "2",
#     "price_usd_total": "33",
#     "room_type_or_description": "Studio",
#     "amenities": ["Entire studio", "1 bathroom", "1 full bed"]
#   },
#   {
#     "hotel_name": "Grand Riviera Suites Studio by MrSayla",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 68 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Grand Riviera Suites Staycation near US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "39",
#     "room_type_or_description": "Standard Studio",
#     "amenities": ["Entire studio", "1 bathroom", "Multiple bed types"]
#   },
#   {
#     "hotel_name": "2BR Grand Riviera Suites by MrSayla",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "2BR Grand Riviera Suites by MrSayla",
#     "amenities": ["N/A"]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 69 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "2BR Grand Riviera Suites Staycation infront of US Embassy by Sayla",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "69",
#     "room_type_or_description": "Two-Bedroom Apartment with Sea View",
#     "amenities": [
#       "Entire apartment",
#       "2 bedrooms",
#       "1 living room",
#       "2 bathrooms",
#       "538.2ft²",
#       "6 beds (2 twins, 1 sofa bed, 1 queen, 2 futons)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "1BR Grand Riviera Suites by MrSayla",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 70 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "1BR Grand Riviera Suites by MRSayla",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.6",
#     "number_of_reviews": "29",
#     "price_usd_total": "50",
#     "room_type_or_description": "One-Bedroom Apartment with Sea View",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "430.6ft²",
#       "3 beds (1 twin, 1 full, 1 sofa bed)"
#     ]
#   },
#   {
#     "hotel_name": "Studio Unit Condotel Rizal Park View Manila View",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "Studio Unit Condotel Rizal Park View Manila View",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 71 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Studio Unit Condotel Rizal Park View",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "48",
#     "room_type_or_description": "Apartment, 1 full bed",
#     "amenities": []
#   },
#   {
#     "hotel_name": "3BR Grand Riviera Suites by MrSayla",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "680",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 72 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "3BR- Grand Riviera Suites by MRSayla",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "9.6",
#     "number_of_reviews": "56",
#     "price_usd_total": "120",
#     "room_type_or_description": "Three-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "3 bedrooms",
#       "1 living room",
#       "2 bathrooms",
#       "914.9ft²",
#       "7 beds (1 bunk bed, 1 sofa bed, 2 queens, 3 futons)"
#     ]
#   },
#   {
#     "hotel_name": "Magnificent View of Manila Bay, Roxas Blvd, US Embassy",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 73 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Magnificent View of Manila Bay Roxas Blvd US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "7.1",
#     "number_of_reviews": "81",
#     "price_usd_total": "47",
#     "room_type_or_description": "One-Bedroom Suite",
#     "amenities": [
#       "Private suite",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "355.2ft²",
#       "4 beds (2 sofa beds, 1 queen, 1 futon)"
#     ]
#   },
#   {
#     "hotel_name": "US Embassy,Manila Bay,St.Lukes,Luxuriuos Condo",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 74 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "US Embassy Manila Bay St Lukes Luxuriuos Condo Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "4.5",
#     "number_of_reviews": "2",
#     "price_usd_total": "39",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "2 beds (1 full, 1 sofa bed)"
#     ]
#   },
#   {
#     "hotel_name": "Grand Riviera Suites Comfy Condo near US Embassy Manila Bay Roxas Blvd Ermita Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 75 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Comfy Condo Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "6.9",
#     "number_of_reviews": "44",
#     "price_usd_total": "49",
#     "room_type_or_description": "Standard Studio",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "215.3ft²",
#       "2 beds (1 full, 1 futon)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Cozy 1BR Condo in Manila Near US Embassy and Robinsons Place Manila",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 76 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Cozy 1BR Condo in Manila near US Embassy and Robinsons Place Manila",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "10",
#     "number_of_reviews": "8",
#     "price_usd_total": "53",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 bathroom",
#       "1 kitchen",
#       "430.6ft²",
#       "2 beds (1 twin, 1 full)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "8 Adriatico",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 77 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "8 Adriatico Condo near US Embassy",
#     "distance_miles": "0",
#     "guest_rating_out_of_10": "8.5",
#     "number_of_reviews": "2",
#     "price_usd_total": "56",
#     "room_type_or_description": "Deluxe Queen Studio",
#     "amenities": [
#       "Entire studio",
#       "1 bathroom",
#       "1 kitchen",
#       "269.1ft²",
#       "2 beds (1 twin, 1 full)"
#     ]
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 78 - Raw AI Output:
# ```json
# [
#   {
# ...
# ```json
# [
#   {
#     "hotel_name": "Budget Transient Capsule Room Makati near Ayala and Buendia Upper Deck",
#     "distance_miles": "1.9",
#     "guest_rating_out_of_10": "5.3",
#     "number_of_reviews": "19",
#     "price_usd_total": "22",
#     "room_type_or_description": "Bunk Bed in Mixed Dormitory Room",
#     "amenities": [
#       "2 beds in dorms",
#       "2 bunk beds"
#     ]
#   },
#   {
#     "hotel_name": "Lavender Shore residences 2BR",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 978 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Lavender Shore Residences 2BR",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "9.2",
#     "number_of_reviews": "5",
#     "price_usd_total": "51",
#     "room_type_or_description": "Deluxe Room",
#     "amenities": ["2 queen beds"]
#   },
#   {
#     "hotel_name": "1br with Balcony near MOA unit 3",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 979 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "1br with balcony near moa unit 3",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "51",
#     "room_type_or_description": "Deluxe One-Bedroom Apartment with Garden View",
#     "amenities": [
#       "2 beds (1 sofa bed, 1 queen)"
#     ]
#   },
#   {
#     "hotel_name": "Shore 2 Residences MOA Pasay Naia",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 980 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Shore 2 Residences MOA Pasay NAIA",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "47",
#     "room_type_or_description": "Apartment with Terrace, Entire apartment • 1 bedroom • 1 living room • 1 bathroom • 1 kitchen • 322.9ft², 2 beds (1 full, 1 sofa bed)",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Friendly Homstay 99",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 981 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Friendly Homstay 99",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "41",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "2 beds (1 full, 1 sofa bed)"
#     ]
#   },
#   {
#     "hotel_name": "Shore 2 Tower 1",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 982 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Shore 2 Tower 1 Pasay",
#   "distance_miles": "2.2",
#   "guest_rating_out_of_10": "1.0",
#   "number_of_reviews": "1",
#   "price_usd_total": "36",
#   "room_type_or_description": "Studio with Balcony",
#   "amenities": ["Entire studio", "1 bathroom", "1 kitchen", "258.3ft²", "2 beds (1 sofa bed, 1 queen)"]
# }
# ```
#
#
# 🔹 Hotel Block 983 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "with 55-inches android tv near moa star city",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "9.5",
#     "number_of_reviews": "4",
#     "price_usd_total": "50",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "1 kitchen",
#       "258.3ft²",
#       "2 beds (1 sofa bed, 1 queen)"
#     ]
#   },
#   {
#     "hotel_name": "SHORE 1 Residences near MOA - Mall of Asia",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 984 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Rhichelles-Breeze Residence",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "5.0",
#     "number_of_reviews": "3",
#     "price_usd_total": "46",
#     "room_type_or_description": "Entire apartment • 1 bedroom • 1 living room • 1 bathroom • 1 kitchen • 322.9ft² 1 king bed",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Shore 1 & 3 Residences MOA 1BR with balcony by darpm",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 985 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Shore Res Moa 1br W Balcony 3rd",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "8.1",
#     "number_of_reviews": "46",
#     "price_usd_total": "54",
#     "room_type_or_description": "Apartment with Pool View",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "1 kitchen",
#       "290.6ft²",
#       "2 beds (1 full, 1 futon)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Luminette Properties",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 986 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Luminette Properties",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "8.0",
#     "number_of_reviews": "1",
#     "price_usd_total": "55",
#     "room_type_or_description": "One-Bedroom Apartment with Balcony and Sea View",
#     "amenities": ["1 full bed"]
#   },
#   {
#     "hotel_name": "Hiraya Staycation",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 987 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Hiraya- Staycation",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "34",
#     "room_type_or_description": "One-Bedroom Apartment with Pool View",
#     "amenities": ["3 beds (1 sofa bed, 1 queen, 1 futon)"]
#   },
#   {
#     "hotel_name": "Seventh Ave",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 988 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Seventh Ave",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "48",
#     "room_type_or_description": "Apartment with City View",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "1 kitchen",
#       "312.2ft²",
#       "4 beds (1 full, 2 sofa beds, 1 futon)"
#     ]
#   },
#   {
#     "hotel_name": "Shore Residences Amenity View Interiored Room",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "225",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 989 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Shore Residences Amenity View Interiored Room",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "10",
#     "number_of_reviews": "1",
#     "price_usd_total": "40",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": ["2 beds (1 king, 1 sofa bed)"]
#   },
#   {
#     "hotel_name": "Luxe Condo Shore2 Residences",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 990 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Luxe Condo-Shore2 Residences",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "7.0",
#     "number_of_reviews": "6",
#     "price_usd_total": "24",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 bathroom",
#       "1 kitchen",
#       "258.3ft²",
#       "1 full bed",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "MOA Staycation at Shore 2",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 991 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "MOA Staycation at Shore 2",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "64",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "1 kitchen",
#       "290.6ft²",
#       "2 beds (1 sofa bed, 1 queen)"
#     ]
#   },
#   {
#     "hotel_name": "S Suite Home",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 992 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "S Suite Home",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "29",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "2 beds (1 full, 1 sofa bed)"
#     ]
#   },
#   {
#     "hotel_name": "Victoria’s Place",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 993 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Victorias-Place",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "8.4",
#     "number_of_reviews": "52",
#     "price_usd_total": "48",
#     "room_type_or_description": "One-Bedroom Apartment",
#     "amenities": [
#       "Entire apartment",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "1 kitchen",
#       "279.9ft²",
#       "2 beds (1 full, 1 sofa bed)"
#     ]
#   },
#   {
#     "hotel_name": "Duxe Suite2 near Moa and Naia Airport Wifi Netflix",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 994 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Duxe Suite2- near MOA and NAIA Airport WIFI Netflix",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "9.5",
#     "number_of_reviews": "2",
#     "price_usd_total": "63",
#     "room_type_or_description": "Suite with Pool View",
#     "amenities": [
#       "Private suite",
#       "1 bedroom",
#       "1 living room",
#       "1 bathroom",
#       "269.1ft²",
#       "3 beds (2 sofa beds, 1 queen)",
#       "Free cancellation"
#     ]
#   },
#   {
#     "hotel_name": "Cozy Bavaria by Cozy Cabins PH",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 995 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Cozy Bavaria by Cozy Cabins PH",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "35",
#     "room_type_or_description": "Apartment with Pool View, 2 beds (1 full, 1 sofa bed)",
#     "amenities": []
#   },
#   {
#     "hotel_name": "Shore Residence Mall of Asia Direct pool",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 996 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Shore 1 Residence Pasay",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "47",
#     "room_type_or_description": "Apartment with Pool View",
#     "amenities": ["2 beds (1 full, 1 sofa bed)"]
#   },
#   {
#     "hotel_name": "Condotel-Shore 2 Residences MOA",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 997 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Condotel Pasay City",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "10",
#     "number_of_reviews": "1",
#     "price_usd_total": "52",
#     "room_type_or_description": "Deluxe Double Room with Sea View",
#     "amenities": ["1 full bed"]
#   },
#   {
#     "hotel_name": "Duxe Suite8 near Moa & Naia Airport Wifi Netflix",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 998 - Raw AI Output:
# ```json
# [
#   {
#     "hotel_name": "Duxe Suite8- near MOA & NAIA Airport Wifi Netflix",
#     "distance_miles": "2.2",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "58",
#     "room_type_or_description": "Suite with Balcony, Private suite • 1 bedroom • 1 living room • 1 bathroom • 290.6ft², 3 beds (1 sofa bed, 1 queen, 1 futon)",
#     "amenities": ["Free cancellation"]
#   },
#   {
#     "hotel_name": "Cityscapes 1 Bedroom Cozy unit in Shore 2",
#     "distance_miles": "N/A",
#     "guest_rating_out_of_10": "N/A",
#     "number_of_reviews": "N/A",
#     "price_usd_total": "N/A",
#     "room_type_or_description": "N/A",
#     "amenities": []
#   }
# ]
# ```
#
#
# 🔹 Hotel Block 999 - Raw AI Output:
# ```json
# {
#   "hotel_name": "Cityscapes 1-Bedroom Cozy Unit in Shore 2",
#   "distance_miles": "2.2",
#   "guest_rating_out_of_10": "N/A",
#   "number_of_reviews": "N/A",
#   "price_usd_total": "34",
#   "room_type_or_description": "One-Bedroom Apartment with Bay View",
#   "amenities": [
#     "Entire apartment",
#     "1 bedroom",
#     "1 living room",
#     "1 bathroom",
#     "1 kitchen",
#     "312.2ft²",
#     "2 beds (1 full, 1 sofa bed)"
#   ]
# }
# ```
#
#
# ✅ Final structured DataFrame preview:
#                                           hotel_name distance_miles  \
# 0                 Comfy Inn Manila Kalaw by Reddoorz              0
# 1  Eton Baypark Manila Studio Unit By Tripleview ...            N/A
# 2    Eton Baypark Manila by Tripleview 2 Lovely Unit              0
# 3                                       Eton Baypark              0
# 4    Stunning Sunset Retreat at Eton Bayview II 2pax            N/A
#
#   guest_rating_out_of_10 number_of_reviews price_usd_total  \
# 0                    8.0                 1              39
# 1                    N/A               N/A             N/A
# 2                    6.8                 7              39
# 3                    6.9               290              40
# 4                    N/A               N/A             N/A
#
#           room_type_or_description  \
# 0                        Twin Room
# 1                              N/A
# 2  Studio Apartment with Queen Bed
# 3                 Studio Apartment
# 4                              N/A
#
#                                            amenities
# 0                                      [2 twin beds]
# 1                                                 []
# 2  [Entire apartment, 1 bedroom, 1 living room, 1...
# 3  [Entire apartment, 1 bedroom, 1 bathroom, 1 ki...
# 4                                                 []

# %%
df_booking_structured = df_booking_structured[df_booking_structured["price_usd_total"] != "N/A"].reset_index(drop=True)
df_booking_structured
# Out:
#                                              hotel_name distance_miles  \
# 0                    Comfy Inn Manila Kalaw by Reddoorz              0
# 1       Eton Baypark Manila by Tripleview 2 Lovely Unit              0
# 2                                          Eton Baypark              0
# 3       Stunning Sunset Retreat at Eton Bayview II 2pax              0
# 4            Luxury Condo in Manila Bay near US Embassy            N/A
# ...                                                 ...            ...
# 1049                     Cozy Bavaria by Cozy Cabins PH            2.2
# 1050                            Shore 1 Residence Pasay            2.2
# 1051                                Condotel Pasay City            2.2
# 1052  Duxe Suite8- near MOA & NAIA Airport Wifi Netflix            2.2
# 1053          Cityscapes 1-Bedroom Cozy Unit in Shore 2            2.2
#
#      guest_rating_out_of_10 number_of_reviews price_usd_total  \
# 0                       8.0                 1              39
# 1                       6.8                 7              39
# 2                       6.9               290              40
# 3                       N/A               N/A              79
# 4                       N/A               N/A             495
# ...                     ...               ...             ...
# 1049                    N/A               N/A              35
# 1050                    N/A               N/A              47
# 1051                     10                 1              52
# 1052                    N/A               N/A              58
# 1053                    N/A               N/A              34
#
#                                room_type_or_description  \
# 0                                             Twin Room
# 1                       Studio Apartment with Queen Bed
# 2                                      Studio Apartment
# 3                                 One-Bedroom Apartment
# 4                                                   N/A
# ...                                                 ...
# 1049  Apartment with Pool View, 2 beds (1 full, 1 so...
# 1050                           Apartment with Pool View
# 1051                   Deluxe Double Room with Sea View
# 1052  Suite with Balcony, Private suite • 1 bedroom ...
# 1053                One-Bedroom Apartment with Bay View
#
#                                               amenities
# 0                                         [2 twin beds]
# 1     [Entire apartment, 1 bedroom, 1 living room, 1...
# 2     [Entire apartment, 1 bedroom, 1 bathroom, 1 ki...
# 3                           [2 beds (1 queen, 1 futon)]
# 4                                                    []
# ...                                                 ...
# 1049                                                 []
# 1050                      [2 beds (1 full, 1 sofa bed)]
# 1051                                       [1 full bed]
# 1052                                [Free cancellation]
# 1053  [Entire apartment, 1 bedroom, 1 living room, 1...
#
# [1054 rows x 7 columns]

# %%
df_booking_structured.to_excel('Booking.com_Analysis_Philippine_ai.xlsx', index = False)
